# %%
import mido

# %%
mid = mido.MidiFile('./Tetris.mid')

# %%
for i, track in enumerate(mid.tracks):
    print(i, track.name)
print(mid.ticks_per_beat)
# Out:
# 0
# 1 Acoustic Grand Piano
# 2 Instrument2
# 1024

# %%
for msg in mid.tracks[1]:
    print(msg)
# Out:
# <meta message device_name name='SmartMusic SoftSynth 1' time=0>
# <meta message track_name name='Acoustic Grand Piano' time=0>
# program_change channel=0 program=0 time=0
# control_change channel=0 control=7 value=101 time=0
# control_change channel=0 control=10 value=64 time=0
# control_change channel=0 control=7 value=110 time=0
# control_change channel=0 control=100 value=0 time=3
# control_change channel=0 control=101 value=0 time=0
# control_change channel=0 control=6 value=12 time=1
# control_change channel=0 control=38 value=0 time=1
# note_on channel=0 note=71 velocity=61 time=5
# note_on channel=0 note=76 velocity=75 time=0
# note_off channel=0 note=71 velocity=0 time=1043
# note_off channel=0 note=76 velocity=0 time=0
# note_on channel=0 note=68 velocity=57 time=1
# note_on channel=0 note=71 velocity=71 time=0
# note_off channel=0 note=68 velocity=0 time=474
# note_off channel=0 note=71 velocity=0 time=30
# note_on channel=0 note=69 velocity=56 time=1
# note_on channel=0 note=72 velocity=70 time=0
# note_off channel=0 note=69 velocity=0 time=479
# note_off channel=0 note=72 velocity=0 time=30
# note_on channel=0 note=71 velocity=59 time=1
# note_on channel=0 note=74 velocity=73 time=0
# note_off channel=0 note=71 velocity=0 time=479
# note_off channel=0 note=74 velocity=0 time=30
# note_on channel=0 note=76 velocity=64 time=1
# note_off channel=0 note=76 velocity=0 time=232
# note_on channel=0 note=74 velocity=64 time=16
# note_off channel=0 note=74 velocity=0 time=241
# note_on channel=0 note=69 velocity=57 time=16
# note_on channel=0 note=72 velocity=71 time=0
# note_off channel=0 note=69 velocity=0 time=474
# note_off channel=0 note=72 velocity=0 time=30
# note_on channel=0 note=68 velocity=56 time=1
# note_on channel=0 note=71 velocity=70 time=0
# note_off channel=0 note=68 velocity=0 time=476
# note_off channel=0 note=71 velocity=0 time=30
# note_on channel=0 note=64 velocity=61 time=5
# note_on channel=0 note=69 velocity=75 time=0
# note_off channel=0 note=64 velocity=0 time=1049
# note_off channel=0 note=69 velocity=0 time=0
# note_on channel=0 note=64 velocity=57 time=1
# note_on channel=0 note=69 velocity=71 time=0
# note_off channel=0 note=64 velocity=0 time=474
# note_off channel=0 note=69 velocity=0 time=30
# note_on channel=0 note=69 velocity=56 time=1
# note_on channel=0 note=72 velocity=70 time=0
# note_off channel=0 note=69 velocity=0 time=479
# note_off channel=0 note=72 velocity=0 time=30
# note_on channel=0 note=72 velocity=59 time=1
# note_on channel=0 note=76 velocity=73 time=0
# note_off channel=0 note=72 velocity=0 time=1014
# note_off channel=0 note=76 velocity=0 time=0
# note_on channel=0 note=71 velocity=57 time=1
# note_on channel=0 note=74 velocity=71 time=0
# note_off channel=0 note=71 velocity=0 time=474
# note_off channel=0 note=74 velocity=0 time=30
# note_on channel=0 note=69 velocity=56 time=1
# note_on channel=0 note=72 velocity=70 time=0
# note_off channel=0 note=69 velocity=0 time=476
# note_off channel=0 note=72 velocity=0 time=30
# note_on channel=0 note=71 velocity=69 time=5
# note_on channel=0 note=68 velocity=69 time=0
# note_off channel=0 note=68 velocity=0 time=511
# note_on channel=0 note=64 velocity=64 time=31
# note_off channel=0 note=64 velocity=0 time=477
# note_on channel=0 note=68 velocity=65 time=31
# note_off channel=0 note=68 velocity=0 time=474
# note_off channel=0 note=71 velocity=0 time=30
# note_on channel=0 note=72 velocity=64 time=1
# note_on channel=0 note=69 velocity=64 time=0
# note_off channel=0 note=72 velocity=0 time=479
# note_off channel=0 note=69 velocity=0 time=0
# note_on channel=0 note=71 velocity=59 time=31
# note_on channel=0 note=74 velocity=73 time=0
# note_off channel=0 note=71 velocity=0 time=1014
# note_off channel=0 note=74 velocity=0 time=0
# note_on channel=0 note=72 velocity=57 time=1
# note_on channel=0 note=76 velocity=71 time=0
# note_off channel=0 note=72 velocity=0 time=1011
# note_off channel=0 note=76 velocity=0 time=0
# note_on channel=0 note=69 velocity=61 time=5
# note_on channel=0 note=72 velocity=75 time=0
# note_off channel=0 note=69 velocity=0 time=1049
# note_off channel=0 note=72 velocity=0 time=0
# note_on channel=0 note=64 velocity=57 time=1
# note_on channel=0 note=69 velocity=71 time=0
# note_off channel=0 note=64 velocity=0 time=1014
# note_off channel=0 note=69 velocity=0 time=0
# note_on channel=0 note=64 velocity=59 time=1
# note_on channel=0 note=69 velocity=73 time=0
# note_off channel=0 note=64 velocity=0 time=2026
# note_off channel=0 note=69 velocity=0 time=0
# note_on channel=0 note=65 velocity=56 time=547
# note_on channel=0 note=74 velocity=70 time=0
# note_off channel=0 note=65 velocity=0 time=1012
# note_off channel=0 note=74 velocity=0 time=0
# note_on channel=0 note=69 velocity=56 time=1
# note_on channel=0 note=77 velocity=70 time=0
# note_off channel=0 note=69 velocity=0 time=479
# note_off channel=0 note=77 velocity=0 time=30
# note_on channel=0 note=81 velocity=67 time=1
# note_on channel=0 note=72 velocity=67 time=0
# note_off channel=0 note=72 velocity=0 time=509
# note_on channel=0 note=72 velocity=52 time=1
# note_off channel=0 note=72 velocity=0 time=247
# note_on channel=0 note=72 velocity=52 time=1
# note_off channel=0 note=81 velocity=0 time=256
# note_on channel=0 note=71 velocity=57 time=1
# note_on channel=0 note=79 velocity=71 time=0
# note_off channel=0 note=72 velocity=0 time=14
# note_off channel=0 note=71 velocity=0 time=460
# note_off channel=0 note=79 velocity=0 time=30
# note_on channel=0 note=69 velocity=56 time=1
# note_on channel=0 note=77 velocity=70 time=0
# note_off channel=0 note=69 velocity=0 time=476
# note_off channel=0 note=77 velocity=0 time=30
# note_on channel=0 note=67 velocity=61 time=5
# note_on channel=0 note=76 velocity=75 time=0
# note_off channel=0 note=67 velocity=0 time=1554
# note_off channel=0 note=76 velocity=0 time=0
# note_on channel=0 note=64 velocity=56 time=1
# note_on channel=0 note=72 velocity=70 time=0
# note_off channel=0 note=64 velocity=0 time=479
# note_off channel=0 note=72 velocity=0 time=30
# note_on channel=0 note=76 velocity=67 time=1
# note_on channel=0 note=67 velocity=67 time=0
# note_off channel=0 note=67 velocity=0 time=479
# note_on channel=0 note=69 velocity=64 time=31
# note_off channel=0 note=69 velocity=0 time=232
# note_on channel=0 note=67 velocity=64 time=16
# note_off channel=0 note=67 velocity=0 time=241
# note_off channel=0 note=76 velocity=0 time=15
# note_on channel=0 note=65 velocity=57 time=1
# note_on channel=0 note=74 velocity=71 time=0
# note_off channel=0 note=65 velocity=0 time=474
# note_off channel=0 note=74 velocity=0 time=30
# note_on channel=0 note=64 velocity=56 time=1
# note_on channel=0 note=72 velocity=70 time=0
# note_off channel=0 note=64 velocity=0 time=476
# note_off channel=0 note=72 velocity=0 time=30
# note_on channel=0 note=71 velocity=69 time=5
# note_on channel=0 note=68 velocity=69 time=0
# note_off channel=0 note=68 velocity=0 time=511
# note_on channel=0 note=64 velocity=64 time=31
# note_off channel=0 note=64 velocity=0 time=477
# note_off channel=0 note=71 velocity=0 time=30
# note_on channel=0 note=68 velocity=57 time=1
# note_on channel=0 note=71 velocity=71 time=0
# note_off channel=0 note=68 velocity=0 time=474
# note_off channel=0 note=71 velocity=0 time=30
# note_on channel=0 note=69 velocity=56 time=1
# note_on channel=0 note=72 velocity=70 time=0
# note_off channel=0 note=69 velocity=0 time=479
# note_off channel=0 note=72 velocity=0 time=30
# note_on channel=0 note=74 velocity=67 time=1
# note_on channel=0 note=71 velocity=67 time=0
# note_off channel=0 note=71 velocity=0 time=479
# note_on channel=0 note=68 velocity=64 time=31
# note_off channel=0 note=68 velocity=0 time=474
# note_off channel=0 note=74 velocity=0 time=30
# note_on channel=0 note=76 velocity=65 time=1
# note_on channel=0 note=72 velocity=65 time=0
# note_off channel=0 note=72 velocity=0 time=474
# note_on channel=0 note=68 velocity=64 time=31
# note_off channel=0 note=68 velocity=0 time=476
# note_off channel=0 note=76 velocity=0 time=30
# note_on channel=0 note=72 velocity=69 time=5
# note_on channel=0 note=69 velocity=69 time=0
# note_off channel=0 note=69 velocity=0 time=511
# note_on channel=0 note=64 velocity=64 time=31
# note_off channel=0 note=64 velocity=0 time=477
# note_off channel=0 note=72 velocity=0 time=30
# note_on channel=0 note=64 velocity=57 time=1
# note_on channel=0 note=69 velocity=67 time=0
# note_off channel=0 note=64 velocity=0 time=1014
# note_off channel=0 note=69 velocity=0 time=0
# note_on channel=0 note=64 velocity=59 time=1
# note_on channel=0 note=69 velocity=73 time=0
# note_off channel=0 note=64 velocity=0 time=1014
# note_off channel=0 note=69 velocity=0 time=0
# note_on channel=0 note=60 velocity=61 time=1017
# note_on channel=0 note=64 velocity=75 time=0
# note_off channel=0 note=60 velocity=0 time=2064
# note_off channel=0 note=64 velocity=0 time=0
# note_on channel=0 note=57 velocity=59 time=1
# note_on channel=0 note=60 velocity=73 time=0
# note_off channel=0 note=57 velocity=0 time=2026
# note_off channel=0 note=60 velocity=0 time=0
# note_on channel=0 note=59 velocity=61 time=5
# note_on channel=0 note=62 velocity=75 time=0
# note_off channel=0 note=59 velocity=0 time=2064
# note_off channel=0 note=62 velocity=0 time=0
# note_on channel=0 note=56 velocity=59 time=1
# note_on channel=0 note=59 velocity=73 time=0
# note_off channel=0 note=56 velocity=0 time=2026
# note_off channel=0 note=59 velocity=0 time=0
# note_on channel=0 note=57 velocity=61 time=5
# note_on channel=0 note=60 velocity=75 time=0
# note_off channel=0 note=57 velocity=0 time=2064
# note_off channel=0 note=60 velocity=0 time=0
# note_on channel=0 note=52 velocity=59 time=1
# note_on channel=0 note=57 velocity=73 time=0
# note_off channel=0 note=52 velocity=0 time=2026
# note_off channel=0 note=57 velocity=0 time=0
# note_on channel=0 note=52 velocity=61 time=5
# note_on channel=0 note=56 velocity=75 time=0
# note_off channel=0 note=52 velocity=0 time=2064
# note_off channel=0 note=56 velocity=0 time=0
# note_on channel=0 note=56 velocity=59 time=1
# note_on channel=0 note=59 velocity=73 time=0
# note_off channel=0 note=56 velocity=0 time=2026
# note_off channel=0 note=59 velocity=0 time=0
# note_on channel=0 note=60 velocity=61 time=5
# note_on channel=0 note=64 velocity=75 time=0
# note_off channel=0 note=60 velocity=0 time=2064
# note_off channel=0 note=64 velocity=0 time=0
# note_on channel=0 note=57 velocity=59 time=1
# note_on channel=0 note=60 velocity=73 time=0
# note_off channel=0 note=57 velocity=0 time=2026
# note_off channel=0 note=60 velocity=0 time=0
# note_on channel=0 note=59 velocity=61 time=5
# note_on channel=0 note=62 velocity=75 time=0
# note_off channel=0 note=59 velocity=0 time=2064
# note_off channel=0 note=62 velocity=0 time=0
# note_on channel=0 note=56 velocity=59 time=1
# note_on channel=0 note=59 velocity=73 time=0
# note_off channel=0 note=56 velocity=0 time=2026
# note_off channel=0 note=59 velocity=0 time=0
# note_on channel=0 note=57 velocity=61 time=5
# note_on channel=0 note=60 velocity=75 time=0
# note_off channel=0 note=57 velocity=0 time=1049
# note_off channel=0 note=60 velocity=0 time=0
# note_on channel=0 note=60 velocity=57 time=1
# note_on channel=0 note=64 velocity=71 time=0
# note_off channel=0 note=60 velocity=0 time=1014
# note_off channel=0 note=64 velocity=0 time=0
# note_on channel=0 note=64 velocity=59 time=1
# note_on channel=0 note=69 velocity=73 time=0
# note_off channel=0 note=64 velocity=0 time=2026
# note_off channel=0 note=69 velocity=0 time=0
# note_on channel=0 note=64 velocity=56 time=5
# note_on channel=0 note=68 velocity=70 time=0
# note_off channel=0 note=64 velocity=0 time=4091
# note_off channel=0 note=68 velocity=0 time=0
# <meta message end_of_track time=31>

# %%
piano_track = mid.tracks[1]

# %%
mid.ticks_per_beat
# Out:
# 1024

# %%
from collections import namedtuple

MIDINote = namedtuple('MIDINote', ['note', 'volume'])
MIDIState = namedtuple('MIDIState', ['time','notes','tempo'])

# %%
from copy import deepcopy

# %%
state_array = []
state = MIDIState(0, set(), 0)

trk_indexes = [0] * len(mid.tracks)
trk_offset_times = [0] * len(mid.tracks)
while True:
    prev_state = deepcopy(state)
    # First, consume all messages up to the current time
    for i, trk in enumerate(mid.tracks):
        cmd_cnt = 0
        while trk_indexes[i] < len(trk):
            msg = trk[trk_indexes[i]]
            if msg.time + trk_offset_times[i] <= state.time:
                trk_offset_times[i] += msg.time
                trk_indexes[i] += 1
                if msg.type == 'set_tempo': 
                    cmd_cnt += 1
                    state = MIDIState(state.time, state.notes, msg.tempo)
                elif msg.type == 'note_on':
                    cmd_cnt += 1
                    state = MIDIState(state.time, state.notes.union({MIDINote(msg.note, int(msg.velocity/10))}), state.tempo)
                elif msg.type == 'note_off':
                    cmd_cnt += 1
                    state = MIDIState(state.time, set(filter(lambda n: n.note != msg.note, state.notes)), state.tempo)
            else:
                break
        #if cmd_cnt > 0:
            #print('Executed %d commands at time %d for track %d' % (cmd_cnt, state.time, i))
    if prev_state != state:
        #print(state)
        #print('Logging state %s at time %d' % (state, state.time))
        state_array.append(state)
        
    # Locate next command to execute
    next_time = 0
    for i, trk in enumerate(mid.tracks):
        if trk_indexes[i] < len(trk):
            next_msg_time = trk[trk_indexes[i]].time - (state.time - trk_offset_times[i])
            if next_time == 0 or next_msg_time < next_time: next_time = next_msg_time
    if next_time == 0:
        break
    #print('Advancing by %d to time %d' % (next_time, state.time + next_time))
    state = MIDIState(state.time + next_time, state.notes, state.tempo)
    
for i,s in enumerate(state_array):
    sorted_notes = list(sorted(s.notes, key=lambda n: n.note))
    sorted_notes = sorted_notes[-2:]
    state_array[i] = MIDIState(s.time, sorted_notes, s.tempo)
    print(state_array[i])
# Out:
# MIDIState(time=0, notes=[], tempo=500003)
# MIDIState(time=10, notes=[MIDINote(note=71, volume=6), MIDINote(note=76, volume=7)], tempo=500003)
# MIDIState(time=546, notes=[MIDINote(note=71, volume=6), MIDINote(note=76, volume=7)], tempo=500003)
# MIDIState(time=576, notes=[MIDINote(note=71, volume=6), MIDINote(note=76, volume=7)], tempo=500003)
# MIDIState(time=1053, notes=[MIDINote(note=52, volume=5)], tempo=500003)
# MIDIState(time=1054, notes=[MIDINote(note=68, volume=5), MIDINote(note=71, volume=7)], tempo=500003)
# MIDIState(time=1084, notes=[MIDINote(note=68, volume=5), MIDINote(note=71, volume=7)], tempo=500003)
# MIDIState(time=1528, notes=[MIDINote(note=40, volume=5), MIDINote(note=71, volume=7)], tempo=500003)
# MIDIState(time=1558, notes=[MIDINote(note=40, volume=5)], tempo=500003)
# MIDIState(time=1559, notes=[MIDINote(note=69, volume=5), MIDINote(note=72, volume=7)], tempo=500003)
# MIDIState(time=1589, notes=[MIDINote(note=69, volume=5), MIDINote(note=72, volume=7)], tempo=500003)
# MIDIState(time=2038, notes=[MIDINote(note=52, volume=5), MIDINote(note=72, volume=7)], tempo=500003)
# MIDIState(time=2068, notes=[MIDINote(note=52, volume=5)], tempo=500003)
# MIDIState(time=2069, notes=[MIDINote(note=71, volume=5), MIDINote(note=74, volume=7)], tempo=500003)
# MIDIState(time=2099, notes=[MIDINote(note=71, volume=5), MIDINote(note=74, volume=7)], tempo=500003)
# MIDIState(time=2304, notes=[MIDINote(note=71, volume=5), MIDINote(note=74, volume=7)], tempo=504434)
# MIDIState(time=2548, notes=[MIDINote(note=40, volume=5), MIDINote(note=74, volume=7)], tempo=504434)
# MIDIState(time=2560, notes=[MIDINote(note=40, volume=5), MIDINote(note=74, volume=7)], tempo=506432)
# MIDIState(time=2578, notes=[MIDINote(note=40, volume=5)], tempo=506432)
# MIDIState(time=2579, notes=[MIDINote(note=52, volume=5), MIDINote(note=76, volume=6)], tempo=506432)
# MIDIState(time=2609, notes=[MIDINote(note=52, volume=5), MIDINote(note=76, volume=6)], tempo=506432)
# MIDIState(time=2811, notes=[MIDINote(note=52, volume=5)], tempo=506432)
# MIDIState(time=2816, notes=[MIDINote(note=52, volume=5)], tempo=508697)
# MIDIState(time=2827, notes=[MIDINote(note=52, volume=5), MIDINote(note=74, volume=6)], tempo=508697)
# MIDIState(time=3068, notes=[MIDINote(note=52, volume=5)], tempo=508697)
# MIDIState(time=3072, notes=[MIDINote(note=52, volume=5)], tempo=513029)
# MIDIState(time=3084, notes=[MIDINote(note=69, volume=5), MIDINote(note=72, volume=7)], tempo=513029)
# MIDIState(time=3114, notes=[MIDINote(note=69, volume=5), MIDINote(note=72, volume=7)], tempo=513029)
# MIDIState(time=3328, notes=[MIDINote(note=69, volume=5), MIDINote(note=72, volume=7)], tempo=515093)
# MIDIState(time=3558, notes=[MIDINote(note=40, volume=5), MIDINote(note=72, volume=7)], tempo=515093)
# MIDIState(time=3584, notes=[MIDINote(note=40, volume=5), MIDINote(note=72, volume=7)], tempo=517436)
# MIDIState(time=3588, notes=[MIDINote(note=40, volume=5)], tempo=517436)
# MIDIState(time=3589, notes=[MIDINote(note=68, volume=5), MIDINote(note=71, volume=7)], tempo=517436)
# MIDIState(time=3619, notes=[MIDINote(note=68, volume=5), MIDINote(note=71, volume=7)], tempo=517436)
# MIDIState(time=3840, notes=[MIDINote(note=68, volume=5), MIDINote(note=71, volume=7)], tempo=519535)
# MIDIState(time=4065, notes=[MIDINote(note=52, volume=5), MIDINote(note=71, volume=7)], tempo=519535)
# MIDIState(time=4095, notes=[MIDINote(note=52, volume=5)], tempo=519535)
# MIDIState(time=4100, notes=[MIDINote(note=64, volume=6), MIDINote(note=69, volume=7)], tempo=519535)
# MIDIState(time=4126, notes=[MIDINote(note=64, volume=6), MIDINote(note=69, volume=7)], tempo=519535)
# MIDIState(time=4352, notes=[MIDINote(note=64, volume=6), MIDINote(note=69, volume=7)], tempo=500003)
# MIDIState(time=4642, notes=[MIDINote(note=64, volume=6), MIDINote(note=69, volume=7)], tempo=500003)
# MIDIState(time=4672, notes=[MIDINote(note=64, volume=6), MIDINote(note=69, volume=7)], tempo=500003)
# MIDIState(time=5149, notes=[MIDINote(note=57, volume=5)], tempo=500003)
# MIDIState(time=5150, notes=[MIDINote(note=64, volume=5), MIDINote(note=69, volume=7)], tempo=500003)
# MIDIState(time=5180, notes=[MIDINote(note=64, volume=5), MIDINote(note=69, volume=7)], tempo=500003)
# MIDIState(time=5624, notes=[MIDINote(note=45, volume=5), MIDINote(note=69, volume=7)], tempo=500003)
# MIDIState(time=5654, notes=[MIDINote(note=45, volume=5)], tempo=500003)
# MIDIState(time=5655, notes=[MIDINote(note=69, volume=5), MIDINote(note=72, volume=7)], tempo=500003)
# MIDIState(time=5685, notes=[MIDINote(note=69, volume=5), MIDINote(note=72, volume=7)], tempo=500003)
# MIDIState(time=6134, notes=[MIDINote(note=57, volume=5), MIDINote(note=72, volume=7)], tempo=500003)
# MIDIState(time=6164, notes=[MIDINote(note=57, volume=5)], tempo=500003)
# MIDIState(time=6165, notes=[MIDINote(note=72, volume=5), MIDINote(note=76, volume=7)], tempo=500003)
# MIDIState(time=6195, notes=[MIDINote(note=72, volume=5), MIDINote(note=76, volume=7)], tempo=500003)
# MIDIState(time=6675, notes=[MIDINote(note=72, volume=5), MIDINote(note=76, volume=7)], tempo=500003)
# MIDIState(time=6705, notes=[MIDINote(note=72, volume=5), MIDINote(note=76, volume=7)], tempo=500003)
# MIDIState(time=7179, notes=[MIDINote(note=57, volume=5)], tempo=500003)
# MIDIState(time=7180, notes=[MIDINote(note=71, volume=5), MIDINote(note=74, volume=7)], tempo=500003)
# MIDIState(time=7210, notes=[MIDINote(note=71, volume=5), MIDINote(note=74, volume=7)], tempo=500003)
# MIDIState(time=7654, notes=[MIDINote(note=45, volume=5), MIDINote(note=74, volume=7)], tempo=500003)
# MIDIState(time=7684, notes=[MIDINote(note=45, volume=5)], tempo=500003)
# MIDIState(time=7685, notes=[MIDINote(note=69, volume=5), MIDINote(note=72, volume=7)], tempo=500003)
# MIDIState(time=7715, notes=[MIDINote(note=69, volume=5), MIDINote(note=72, volume=7)], tempo=500003)
# MIDIState(time=8161, notes=[MIDINote(note=57, volume=5), MIDINote(note=72, volume=7)], tempo=500003)
# MIDIState(time=8191, notes=[MIDINote(note=57, volume=5)], tempo=500003)
# MIDIState(time=8196, notes=[MIDINote(note=68, volume=6), MIDINote(note=71, volume=6)], tempo=500003)
# MIDIState(time=8222, notes=[MIDINote(note=68, volume=6), MIDINote(note=71, volume=6)], tempo=500003)
# MIDIState(time=8707, notes=[MIDINote(note=44, volume=5), MIDINote(note=71, volume=6)], tempo=500003)
# MIDIState(time=8738, notes=[MIDINote(note=64, volume=6), MIDINote(note=71, volume=6)], tempo=500003)
# MIDIState(time=8768, notes=[MIDINote(note=64, volume=6), MIDINote(note=71, volume=6)], tempo=500003)
# MIDIState(time=9215, notes=[MIDINote(note=56, volume=5), MIDINote(note=71, volume=6)], tempo=500003)
# MIDIState(time=9246, notes=[MIDINote(note=68, volume=6), MIDINote(note=71, volume=6)], tempo=500003)
# MIDIState(time=9276, notes=[MIDINote(note=68, volume=6), MIDINote(note=71, volume=6)], tempo=500003)
# MIDIState(time=9720, notes=[MIDINote(note=44, volume=5), MIDINote(note=71, volume=6)], tempo=500003)
# MIDIState(time=9750, notes=[MIDINote(note=44, volume=5)], tempo=500003)
# MIDIState(time=9751, notes=[MIDINote(note=69, volume=6), MIDINote(note=72, volume=6)], tempo=500003)
# MIDIState(time=9781, notes=[MIDINote(note=69, volume=6), MIDINote(note=72, volume=6)], tempo=500003)
# MIDIState(time=10230, notes=[MIDINote(note=56, volume=5)], tempo=500003)
# MIDIState(time=10261, notes=[MIDINote(note=71, volume=5), MIDINote(note=74, volume=7)], tempo=500003)
# MIDIState(time=10291, notes=[MIDINote(note=71, volume=5), MIDINote(note=74, volume=7)], tempo=500003)
# MIDIState(time=10496, notes=[MIDINote(note=71, volume=5), MIDINote(note=74, volume=7)], tempo=504434)
# MIDIState(time=10752, notes=[MIDINote(note=71, volume=5), MIDINote(note=74, volume=7)], tempo=506432)
# MIDIState(time=10771, notes=[MIDINote(note=71, volume=5), MIDINote(note=74, volume=7)], tempo=506432)
# MIDIState(time=10801, notes=[MIDINote(note=71, volume=5), MIDINote(note=74, volume=7)], tempo=506432)
# MIDIState(time=11008, notes=[MIDINote(note=71, volume=5), MIDINote(note=74, volume=7)], tempo=508697)
# MIDIState(time=11264, notes=[MIDINote(note=71, volume=5), MIDINote(note=74, volume=7)], tempo=513029)
# MIDIState(time=11275, notes=[MIDINote(note=52, volume=5)], tempo=513029)
# MIDIState(time=11276, notes=[MIDINote(note=72, volume=5), MIDINote(note=76, volume=7)], tempo=513029)
# MIDIState(time=11306, notes=[MIDINote(note=72, volume=5), MIDINote(note=76, volume=7)], tempo=513029)
# MIDIState(time=11520, notes=[MIDINote(note=72, volume=5), MIDINote(note=76, volume=7)], tempo=515093)
# MIDIState(time=11776, notes=[MIDINote(note=72, volume=5), MIDINote(note=76, volume=7)], tempo=517436)
# MIDIState(time=11781, notes=[MIDINote(note=72, volume=5), MIDINote(note=76, volume=7)], tempo=517436)
# MIDIState(time=11811, notes=[MIDINote(note=72, volume=5), MIDINote(note=76, volume=7)], tempo=517436)
# MIDIState(time=12032, notes=[MIDINote(note=72, volume=5), MIDINote(note=76, volume=7)], tempo=519535)
# MIDIState(time=12287, notes=[MIDINote(note=52, volume=5)], tempo=519535)
# MIDIState(time=12292, notes=[MIDINote(note=69, volume=6), MIDINote(note=72, volume=7)], tempo=519535)
# MIDIState(time=12318, notes=[MIDINote(note=69, volume=6), MIDINote(note=72, volume=7)], tempo=519535)
# MIDIState(time=12544, notes=[MIDINote(note=69, volume=6), MIDINote(note=72, volume=7)], tempo=500003)
# MIDIState(time=12834, notes=[MIDINote(note=69, volume=6), MIDINote(note=72, volume=7)], tempo=500003)
# MIDIState(time=12864, notes=[MIDINote(note=69, volume=6), MIDINote(note=72, volume=7)], tempo=500003)
# MIDIState(time=13341, notes=[MIDINote(note=57, volume=5)], tempo=500003)
# MIDIState(time=13342, notes=[MIDINote(note=64, volume=5), MIDINote(note=69, volume=7)], tempo=500003)
# MIDIState(time=13372, notes=[MIDINote(note=64, volume=5), MIDINote(note=69, volume=7)], tempo=500003)
# MIDIState(time=13847, notes=[MIDINote(note=64, volume=5), MIDINote(note=69, volume=7)], tempo=500003)
# MIDIState(time=13877, notes=[MIDINote(note=64, volume=5), MIDINote(note=69, volume=7)], tempo=500003)
# MIDIState(time=14356, notes=[MIDINote(note=57, volume=5)], tempo=500003)
# MIDIState(time=14357, notes=[MIDINote(note=64, volume=5), MIDINote(note=69, volume=7)], tempo=500003)
# MIDIState(time=14387, notes=[MIDINote(note=64, volume=5), MIDINote(note=69, volume=7)], tempo=500003)
# MIDIState(time=14867, notes=[MIDINote(note=64, volume=5), MIDINote(note=69, volume=7)], tempo=500003)
# MIDIState(time=14897, notes=[MIDINote(note=64, volume=5), MIDINote(note=69, volume=7)], tempo=500003)
# MIDIState(time=15372, notes=[MIDINote(note=64, volume=5), MIDINote(note=69, volume=7)], tempo=500003)
# MIDIState(time=15402, notes=[MIDINote(note=64, volume=5), MIDINote(note=69, volume=7)], tempo=500003)
# MIDIState(time=15877, notes=[MIDINote(note=64, volume=5), MIDINote(note=69, volume=7)], tempo=500003)
# MIDIState(time=15907, notes=[MIDINote(note=64, volume=5), MIDINote(note=69, volume=7)], tempo=500003)
# MIDIState(time=16383, notes=[MIDINote(note=48, volume=5)], tempo=500003)
# MIDIState(time=16388, notes=[MIDINote(note=48, volume=5), MIDINote(note=50, volume=5)], tempo=500003)
# MIDIState(time=16414, notes=[MIDINote(note=50, volume=5)], tempo=500003)
# MIDIState(time=16930, notes=[MIDINote(note=65, volume=5), MIDINote(note=74, volume=7)], tempo=500003)
# MIDIState(time=16960, notes=[MIDINote(note=65, volume=5), MIDINote(note=74, volume=7)], tempo=500003)
# MIDIState(time=17468, notes=[MIDINote(note=65, volume=5), MIDINote(note=74, volume=7)], tempo=500003)
# MIDIState(time=17942, notes=[], tempo=500003)
# MIDIState(time=17943, notes=[MIDINote(note=69, volume=5), MIDINote(note=77, volume=7)], tempo=500003)
# MIDIState(time=18422, notes=[MIDINote(note=38, volume=5), MIDINote(note=77, volume=7)], tempo=500003)
# MIDIState(time=18452, notes=[MIDINote(note=38, volume=5)], tempo=500003)
# MIDIState(time=18453, notes=[MIDINote(note=72, volume=6), MIDINote(note=81, volume=6)], tempo=500003)
# MIDIState(time=18483, notes=[MIDINote(note=72, volume=6), MIDINote(note=81, volume=6)], tempo=500003)
# MIDIState(time=18688, notes=[MIDINote(note=72, volume=6), MIDINote(note=81, volume=6)], tempo=502210)
# MIDIState(time=18944, notes=[MIDINote(note=72, volume=6), MIDINote(note=81, volume=6)], tempo=504434)
# MIDIState(time=18962, notes=[MIDINote(note=81, volume=6)], tempo=504434)
# MIDIState(time=18963, notes=[MIDINote(note=72, volume=5), MIDINote(note=81, volume=6)], tempo=504434)
# MIDIState(time=19210, notes=[MIDINote(note=38, volume=5), MIDINote(note=81, volume=6)], tempo=504434)
# MIDIState(time=19211, notes=[MIDINote(note=72, volume=5), MIDINote(note=81, volume=6)], tempo=504434)
# MIDIState(time=19456, notes=[MIDINote(note=72, volume=5), MIDINote(note=81, volume=6)], tempo=506432)
# MIDIState(time=19467, notes=[MIDINote(note=38, volume=5), MIDINote(note=72, volume=5)], tempo=506432)
# MIDIState(time=19468, notes=[MIDINote(note=72, volume=5), MIDINote(note=79, volume=7)], tempo=506432)
# MIDIState(time=19482, notes=[MIDINote(note=71, volume=5), MIDINote(note=79, volume=7)], tempo=506432)
# MIDIState(time=19498, notes=[MIDINote(note=71, volume=5), MIDINote(note=79, volume=7)], tempo=506432)
# MIDIState(time=19942, notes=[MIDINote(note=45, volume=5), MIDINote(note=79, volume=7)], tempo=506432)
# MIDIState(time=19968, notes=[MIDINote(note=45, volume=5), MIDINote(note=79, volume=7)], tempo=508697)
# MIDIState(time=19972, notes=[MIDINote(note=45, volume=5)], tempo=508697)
# MIDIState(time=19973, notes=[MIDINote(note=69, volume=5), MIDINote(note=77, volume=7)], tempo=508697)
# MIDIState(time=20003, notes=[MIDINote(note=69, volume=5), MIDINote(note=77, volume=7)], tempo=508697)
# MIDIState(time=20224, notes=[MIDINote(note=69, volume=5), MIDINote(note=77, volume=7)], tempo=510726)
# MIDIState(time=20449, notes=[MIDINote(note=41, volume=5), MIDINote(note=77, volume=7)], tempo=510726)
# MIDIState(time=20479, notes=[MIDINote(note=41, volume=5)], tempo=510726)
# MIDIState(time=20480, notes=[MIDINote(note=41, volume=5)], tempo=500003)
# MIDIState(time=20484, notes=[MIDINote(note=67, volume=6), MIDINote(note=76, volume=7)], tempo=500003)
# MIDIState(time=20510, notes=[MIDINote(note=67, volume=6), MIDINote(note=76, volume=7)], tempo=500003)
# MIDIState(time=21026, notes=[MIDINote(note=67, volume=6), MIDINote(note=76, volume=7)], tempo=500003)
# MIDIState(time=21056, notes=[MIDINote(note=67, volume=6), MIDINote(note=76, volume=7)], tempo=500003)
# MIDIState(time=21564, notes=[MIDINote(note=67, volume=6), MIDINote(note=76, volume=7)], tempo=500003)
# MIDIState(time=22038, notes=[], tempo=500003)
# MIDIState(time=22039, notes=[MIDINote(note=64, volume=5), MIDINote(note=72, volume=7)], tempo=500003)
# MIDIState(time=22518, notes=[MIDINote(note=48, volume=5), MIDINote(note=72, volume=7)], tempo=500003)
# MIDIState(time=22548, notes=[MIDINote(note=48, volume=5)], tempo=500003)
# MIDIState(time=22549, notes=[MIDINote(note=67, volume=6), MIDINote(note=76, volume=6)], tempo=500003)
# MIDIState(time=22579, notes=[MIDINote(note=67, volume=6), MIDINote(note=76, volume=6)], tempo=500003)
# MIDIState(time=23028, notes=[MIDINote(note=36, volume=5), MIDINote(note=76, volume=6)], tempo=500003)
# MIDIState(time=23059, notes=[MIDINote(note=69, volume=6), MIDINote(note=76, volume=6)], tempo=500003)
# MIDIState(time=23089, notes=[MIDINote(note=69, volume=6), MIDINote(note=76, volume=6)], tempo=500003)
# MIDIState(time=23291, notes=[MIDINote(note=43, volume=5), MIDINote(note=76, volume=6)], tempo=500003)
# MIDIState(time=23307, notes=[MIDINote(note=67, volume=6), MIDINote(note=76, volume=6)], tempo=500003)
# MIDIState(time=23548, notes=[MIDINote(note=43, volume=5), MIDINote(note=76, volume=6)], tempo=500003)
# MIDIState(time=23563, notes=[MIDINote(note=43, volume=5)], tempo=500003)
# MIDIState(time=23564, notes=[MIDINote(note=65, volume=5), MIDINote(note=74, volume=7)], tempo=500003)
# MIDIState(time=23594, notes=[MIDINote(note=65, volume=5), MIDINote(note=74, volume=7)], tempo=500003)
# MIDIState(time=24038, notes=[MIDINote(note=74, volume=7)], tempo=500003)
# MIDIState(time=24068, notes=[], tempo=500003)
# MIDIState(time=24069, notes=[MIDINote(note=64, volume=5), MIDINote(note=72, volume=7)], tempo=500003)
# MIDIState(time=24545, notes=[MIDINote(note=43, volume=5), MIDINote(note=72, volume=7)], tempo=500003)
# MIDIState(time=24575, notes=[MIDINote(note=43, volume=5)], tempo=500003)
# MIDIState(time=24580, notes=[MIDINote(note=68, volume=6), MIDINote(note=71, volume=6)], tempo=500003)
# MIDIState(time=24606, notes=[MIDINote(note=68, volume=6), MIDINote(note=71, volume=6)], tempo=500003)
# MIDIState(time=25091, notes=[MIDINote(note=47, volume=5), MIDINote(note=71, volume=6)], tempo=500003)
# MIDIState(time=25122, notes=[MIDINote(note=64, volume=6), MIDINote(note=71, volume=6)], tempo=500003)
# MIDIState(time=25152, notes=[MIDINote(note=64, volume=6), MIDINote(note=71, volume=6)], tempo=500003)
# MIDIState(time=25599, notes=[MIDINote(note=59, volume=5), MIDINote(note=71, volume=6)], tempo=500003)
# MIDIState(time=25629, notes=[MIDINote(note=59, volume=5)], tempo=500003)
# MIDIState(time=25630, notes=[MIDINote(note=68, volume=5), MIDINote(note=71, volume=7)], tempo=500003)
# MIDIState(time=25660, notes=[MIDINote(note=68, volume=5), MIDINote(note=71, volume=7)], tempo=500003)
# MIDIState(time=26104, notes=[MIDINote(note=71, volume=7)], tempo=500003)
# MIDIState(time=26134, notes=[], tempo=500003)
# MIDIState(time=26135, notes=[MIDINote(note=69, volume=5), MIDINote(note=72, volume=7)], tempo=500003)
# MIDIState(time=26614, notes=[MIDINote(note=59, volume=5), MIDINote(note=72, volume=7)], tempo=500003)
# MIDIState(time=26644, notes=[MIDINote(note=59, volume=5)], tempo=500003)
# MIDIState(time=26645, notes=[MIDINote(note=71, volume=6), MIDINote(note=74, volume=6)], tempo=500003)
# MIDIState(time=26675, notes=[MIDINote(note=71, volume=6), MIDINote(note=74, volume=6)], tempo=500003)
# MIDIState(time=27124, notes=[MIDINote(note=74, volume=6)], tempo=500003)
# MIDIState(time=27155, notes=[MIDINote(note=68, volume=6), MIDINote(note=74, volume=6)], tempo=500003)
# MIDIState(time=27629, notes=[MIDINote(note=52, volume=5), MIDINote(note=74, volume=6)], tempo=500003)
# MIDIState(time=27659, notes=[MIDINote(note=52, volume=5)], tempo=500003)
# MIDIState(time=27660, notes=[MIDINote(note=72, volume=6), MIDINote(note=76, volume=6)], tempo=500003)
# MIDIState(time=27690, notes=[MIDINote(note=72, volume=6), MIDINote(note=76, volume=6)], tempo=500003)
# MIDIState(time=28134, notes=[MIDINote(note=76, volume=6)], tempo=500003)
# MIDIState(time=28165, notes=[MIDINote(note=68, volume=6), MIDINote(note=76, volume=6)], tempo=500003)
# MIDIState(time=28641, notes=[MIDINote(note=56, volume=5), MIDINote(note=76, volume=6)], tempo=500003)
# MIDIState(time=28671, notes=[MIDINote(note=56, volume=5)], tempo=500003)
# MIDIState(time=28676, notes=[MIDINote(note=69, volume=6), MIDINote(note=72, volume=6)], tempo=500003)
# MIDIState(time=28702, notes=[MIDINote(note=69, volume=6), MIDINote(note=72, volume=6)], tempo=500003)
# MIDIState(time=29187, notes=[MIDINote(note=45, volume=5), MIDINote(note=72, volume=6)], tempo=500003)
# MIDIState(time=29218, notes=[MIDINote(note=64, volume=6), MIDINote(note=72, volume=6)], tempo=500003)
# MIDIState(time=29248, notes=[MIDINote(note=64, volume=6), MIDINote(note=72, volume=6)], tempo=500003)
# MIDIState(time=29695, notes=[MIDINote(note=52, volume=5), MIDINote(note=72, volume=6)], tempo=500003)
# MIDIState(time=29725, notes=[MIDINote(note=52, volume=5)], tempo=500003)
# MIDIState(time=29726, notes=[MIDINote(note=64, volume=5), MIDINote(note=69, volume=6)], tempo=500003)
# MIDIState(time=29756, notes=[MIDINote(note=64, volume=5), MIDINote(note=69, volume=6)], tempo=500003)
# MIDIState(time=30231, notes=[MIDINote(note=64, volume=5), MIDINote(note=69, volume=6)], tempo=500003)
# MIDIState(time=30261, notes=[MIDINote(note=64, volume=5), MIDINote(note=69, volume=6)], tempo=500003)
# MIDIState(time=30740, notes=[MIDINote(note=52, volume=5)], tempo=500003)
# MIDIState(time=30741, notes=[MIDINote(note=64, volume=5), MIDINote(note=69, volume=7)], tempo=500003)
# MIDIState(time=30771, notes=[MIDINote(note=64, volume=5), MIDINote(note=69, volume=7)], tempo=500003)
# MIDIState(time=31755, notes=[], tempo=500003)
# MIDIState(time=32772, notes=[MIDINote(note=60, volume=6), MIDINote(note=64, volume=7)], tempo=500003)
# MIDIState(time=33314, notes=[MIDINote(note=60, volume=6), MIDINote(note=64, volume=7)], tempo=500003)
# MIDIState(time=33344, notes=[MIDINote(note=60, volume=6), MIDINote(note=64, volume=7)], tempo=500003)
# MIDIState(time=33822, notes=[MIDINote(note=60, volume=6), MIDINote(note=64, volume=7)], tempo=500003)
# MIDIState(time=33852, notes=[MIDINote(note=60, volume=6), MIDINote(note=64, volume=7)], tempo=500003)
# MIDIState(time=34327, notes=[MIDINote(note=60, volume=6), MIDINote(note=64, volume=7)], tempo=500003)
# MIDIState(time=34357, notes=[MIDINote(note=60, volume=6), MIDINote(note=64, volume=7)], tempo=500003)
# MIDIState(time=34836, notes=[MIDINote(note=52, volume=5)], tempo=500003)
# MIDIState(time=34837, notes=[MIDINote(note=57, volume=5), MIDINote(note=60, volume=7)], tempo=500003)
# MIDIState(time=34867, notes=[MIDINote(note=57, volume=5), MIDINote(note=60, volume=7)], tempo=500003)
# MIDIState(time=35347, notes=[MIDINote(note=57, volume=5), MIDINote(note=60, volume=7)], tempo=500003)
# MIDIState(time=35377, notes=[MIDINote(note=57, volume=5), MIDINote(note=60, volume=7)], tempo=500003)
# MIDIState(time=35852, notes=[MIDINote(note=57, volume=5), MIDINote(note=60, volume=7)], tempo=500003)
# MIDIState(time=35882, notes=[MIDINote(note=57, volume=5), MIDINote(note=60, volume=7)], tempo=500003)
# MIDIState(time=36357, notes=[MIDINote(note=57, volume=5), MIDINote(note=60, volume=7)], tempo=500003)
# MIDIState(time=36387, notes=[MIDINote(note=57, volume=5), MIDINote(note=60, volume=7)], tempo=500003)
# MIDIState(time=36863, notes=[MIDINote(note=52, volume=5)], tempo=500003)
# MIDIState(time=36868, notes=[MIDINote(note=59, volume=6), MIDINote(note=62, volume=7)], tempo=500003)
# MIDIState(time=36894, notes=[MIDINote(note=59, volume=6), MIDINote(note=62, volume=7)], tempo=500003)
# MIDIState(time=37410, notes=[MIDINote(note=59, volume=6), MIDINote(note=62, volume=7)], tempo=500003)
# MIDIState(time=37440, notes=[MIDINote(note=59, volume=6), MIDINote(note=62, volume=7)], tempo=500003)
# MIDIState(time=37918, notes=[MIDINote(note=59, volume=6), MIDINote(note=62, volume=7)], tempo=500003)
# MIDIState(time=37948, notes=[MIDINote(note=59, volume=6), MIDINote(note=62, volume=7)], tempo=500003)
# MIDIState(time=38423, notes=[MIDINote(note=59, volume=6), MIDINote(note=62, volume=7)], tempo=500003)
# MIDIState(time=38453, notes=[MIDINote(note=59, volume=6), MIDINote(note=62, volume=7)], tempo=500003)
# MIDIState(time=38932, notes=[MIDINote(note=52, volume=5)], tempo=500003)
# MIDIState(time=38933, notes=[MIDINote(note=56, volume=5), MIDINote(note=59, volume=7)], tempo=500003)
# MIDIState(time=38963, notes=[MIDINote(note=56, volume=5), MIDINote(note=59, volume=7)], tempo=500003)
# MIDIState(time=39168, notes=[MIDINote(note=56, volume=5), MIDINote(note=59, volume=7)], tempo=504434)
# MIDIState(time=39424, notes=[MIDINote(note=56, volume=5), MIDINote(note=59, volume=7)], tempo=506432)
# MIDIState(time=39443, notes=[MIDINote(note=56, volume=5), MIDINote(note=59, volume=7)], tempo=506432)
# MIDIState(time=39473, notes=[MIDINote(note=56, volume=5), MIDINote(note=59, volume=7)], tempo=506432)
# MIDIState(time=39680, notes=[MIDINote(note=56, volume=5), MIDINote(note=59, volume=7)], tempo=508697)
# MIDIState(time=39936, notes=[MIDINote(note=56, volume=5), MIDINote(note=59, volume=7)], tempo=513029)
# MIDIState(time=39948, notes=[MIDINote(note=56, volume=5), MIDINote(note=59, volume=7)], tempo=513029)
# MIDIState(time=39978, notes=[MIDINote(note=56, volume=5), MIDINote(note=59, volume=7)], tempo=513029)
# MIDIState(time=40192, notes=[MIDINote(note=56, volume=5), MIDINote(note=59, volume=7)], tempo=515093)
# MIDIState(time=40448, notes=[MIDINote(note=56, volume=5), MIDINote(note=59, volume=7)], tempo=517436)
# MIDIState(time=40453, notes=[MIDINote(note=56, volume=5), MIDINote(note=59, volume=7)], tempo=517436)
# MIDIState(time=40483, notes=[MIDINote(note=56, volume=5), MIDINote(note=59, volume=7)], tempo=517436)
# MIDIState(time=40704, notes=[MIDINote(note=56, volume=5), MIDINote(note=59, volume=7)], tempo=519535)
# MIDIState(time=40959, notes=[MIDINote(note=52, volume=5)], tempo=519535)
# MIDIState(time=40964, notes=[MIDINote(note=57, volume=6), MIDINote(note=60, volume=7)], tempo=519535)
# MIDIState(time=40990, notes=[MIDINote(note=57, volume=6), MIDINote(note=60, volume=7)], tempo=519535)
# MIDIState(time=41216, notes=[MIDINote(note=57, volume=6), MIDINote(note=60, volume=7)], tempo=500003)
# MIDIState(time=41506, notes=[MIDINote(note=57, volume=6), MIDINote(note=60, volume=7)], tempo=500003)
# MIDIState(time=41536, notes=[MIDINote(note=57, volume=6), MIDINote(note=60, volume=7)], tempo=500003)
# MIDIState(time=42014, notes=[MIDINote(note=57, volume=6), MIDINote(note=60, volume=7)], tempo=500003)
# MIDIState(time=42044, notes=[MIDINote(note=57, volume=6), MIDINote(note=60, volume=7)], tempo=500003)
# MIDIState(time=42519, notes=[MIDINote(note=57, volume=6), MIDINote(note=60, volume=7)], tempo=500003)
# MIDIState(time=42549, notes=[MIDINote(note=57, volume=6), MIDINote(note=60, volume=7)], tempo=500003)
# MIDIState(time=43028, notes=[MIDINote(note=52, volume=5)], tempo=500003)
# MIDIState(time=43029, notes=[MIDINote(note=52, volume=5), MIDINote(note=57, volume=7)], tempo=500003)
# MIDIState(time=43059, notes=[MIDINote(note=45, volume=5), MIDINote(note=57, volume=7)], tempo=500003)
# MIDIState(time=43539, notes=[MIDINote(note=52, volume=5), MIDINote(note=57, volume=7)], tempo=500003)
# MIDIState(time=43569, notes=[MIDINote(note=52, volume=5), MIDINote(note=57, volume=7)], tempo=500003)
# MIDIState(time=44044, notes=[MIDINote(note=52, volume=5), MIDINote(note=57, volume=7)], tempo=500003)
# MIDIState(time=44074, notes=[MIDINote(note=45, volume=5), MIDINote(note=57, volume=7)], tempo=500003)
# MIDIState(time=44549, notes=[MIDINote(note=52, volume=5), MIDINote(note=57, volume=7)], tempo=500003)
# MIDIState(time=44579, notes=[MIDINote(note=52, volume=5), MIDINote(note=57, volume=7)], tempo=500003)
# MIDIState(time=45055, notes=[], tempo=500003)
# MIDIState(time=45060, notes=[MIDINote(note=52, volume=6), MIDINote(note=56, volume=7)], tempo=500003)
# MIDIState(time=45086, notes=[MIDINote(note=44, volume=5), MIDINote(note=56, volume=7)], tempo=500003)
# MIDIState(time=45602, notes=[MIDINote(note=52, volume=5), MIDINote(note=56, volume=7)], tempo=500003)
# MIDIState(time=45632, notes=[MIDINote(note=52, volume=5), MIDINote(note=56, volume=7)], tempo=500003)
# MIDIState(time=46110, notes=[MIDINote(note=52, volume=5), MIDINote(note=56, volume=7)], tempo=500003)
# MIDIState(time=46140, notes=[MIDINote(note=44, volume=5), MIDINote(note=56, volume=7)], tempo=500003)
# MIDIState(time=46615, notes=[MIDINote(note=52, volume=5), MIDINote(note=56, volume=7)], tempo=500003)
# MIDIState(time=46645, notes=[MIDINote(note=52, volume=5), MIDINote(note=56, volume=7)], tempo=500003)
# MIDIState(time=47124, notes=[], tempo=500003)
# MIDIState(time=47125, notes=[MIDINote(note=56, volume=5), MIDINote(note=59, volume=7)], tempo=500003)
# MIDIState(time=47360, notes=[MIDINote(note=56, volume=5), MIDINote(note=59, volume=7)], tempo=504434)
# MIDIState(time=47616, notes=[MIDINote(note=56, volume=5), MIDINote(note=59, volume=7)], tempo=506432)
# MIDIState(time=47635, notes=[MIDINote(note=56, volume=5), MIDINote(note=59, volume=7)], tempo=506432)
# MIDIState(time=47665, notes=[MIDINote(note=56, volume=5), MIDINote(note=59, volume=7)], tempo=506432)
# MIDIState(time=47872, notes=[MIDINote(note=56, volume=5), MIDINote(note=59, volume=7)], tempo=508697)
# MIDIState(time=48128, notes=[MIDINote(note=56, volume=5), MIDINote(note=59, volume=7)], tempo=513029)
# MIDIState(time=48140, notes=[MIDINote(note=56, volume=5), MIDINote(note=59, volume=7)], tempo=513029)
# MIDIState(time=48170, notes=[MIDINote(note=56, volume=5), MIDINote(note=59, volume=7)], tempo=513029)
# MIDIState(time=48384, notes=[MIDINote(note=56, volume=5), MIDINote(note=59, volume=7)], tempo=515093)
# MIDIState(time=48640, notes=[MIDINote(note=56, volume=5), MIDINote(note=59, volume=7)], tempo=517436)
# MIDIState(time=48645, notes=[MIDINote(note=56, volume=5), MIDINote(note=59, volume=7)], tempo=517436)
# MIDIState(time=48675, notes=[MIDINote(note=56, volume=5), MIDINote(note=59, volume=7)], tempo=517436)
# MIDIState(time=48896, notes=[MIDINote(note=56, volume=5), MIDINote(note=59, volume=7)], tempo=519535)
# MIDIState(time=49151, notes=[MIDINote(note=52, volume=5)], tempo=519535)
# MIDIState(time=49156, notes=[MIDINote(note=60, volume=6), MIDINote(note=64, volume=7)], tempo=519535)
# MIDIState(time=49182, notes=[MIDINote(note=60, volume=6), MIDINote(note=64, volume=7)], tempo=519535)
# MIDIState(time=49408, notes=[MIDINote(note=60, volume=6), MIDINote(note=64, volume=7)], tempo=500003)
# MIDIState(time=49698, notes=[MIDINote(note=60, volume=6), MIDINote(note=64, volume=7)], tempo=500003)
# MIDIState(time=49728, notes=[MIDINote(note=60, volume=6), MIDINote(note=64, volume=7)], tempo=500003)
# MIDIState(time=50206, notes=[MIDINote(note=60, volume=6), MIDINote(note=64, volume=7)], tempo=500003)
# MIDIState(time=50236, notes=[MIDINote(note=60, volume=6), MIDINote(note=64, volume=7)], tempo=500003)
# MIDIState(time=50711, notes=[MIDINote(note=60, volume=6), MIDINote(note=64, volume=7)], tempo=500003)
# MIDIState(time=50741, notes=[MIDINote(note=60, volume=6), MIDINote(note=64, volume=7)], tempo=500003)
# MIDIState(time=51220, notes=[MIDINote(note=52, volume=5)], tempo=500003)
# MIDIState(time=51221, notes=[MIDINote(note=57, volume=5), MIDINote(note=60, volume=7)], tempo=500003)
# MIDIState(time=51251, notes=[MIDINote(note=57, volume=5), MIDINote(note=60, volume=7)], tempo=500003)
# MIDIState(time=51731, notes=[MIDINote(note=57, volume=5), MIDINote(note=60, volume=7)], tempo=500003)
# MIDIState(time=51761, notes=[MIDINote(note=57, volume=5), MIDINote(note=60, volume=7)], tempo=500003)
# MIDIState(time=52236, notes=[MIDINote(note=57, volume=5), MIDINote(note=60, volume=7)], tempo=500003)
# MIDIState(time=52266, notes=[MIDINote(note=57, volume=5), MIDINote(note=60, volume=7)], tempo=500003)
# MIDIState(time=52741, notes=[MIDINote(note=57, volume=5), MIDINote(note=60, volume=7)], tempo=500003)
# MIDIState(time=52771, notes=[MIDINote(note=57, volume=5), MIDINote(note=60, volume=7)], tempo=500003)
# MIDIState(time=53247, notes=[MIDINote(note=52, volume=5)], tempo=500003)
# MIDIState(time=53252, notes=[MIDINote(note=59, volume=6), MIDINote(note=62, volume=7)], tempo=500003)
# MIDIState(time=53278, notes=[MIDINote(note=59, volume=6), MIDINote(note=62, volume=7)], tempo=500003)
# MIDIState(time=53794, notes=[MIDINote(note=59, volume=6), MIDINote(note=62, volume=7)], tempo=500003)
# MIDIState(time=53824, notes=[MIDINote(note=59, volume=6), MIDINote(note=62, volume=7)], tempo=500003)
# MIDIState(time=54302, notes=[MIDINote(note=59, volume=6), MIDINote(note=62, volume=7)], tempo=500003)
# MIDIState(time=54332, notes=[MIDINote(note=59, volume=6), MIDINote(note=62, volume=7)], tempo=500003)
# MIDIState(time=54807, notes=[MIDINote(note=59, volume=6), MIDINote(note=62, volume=7)], tempo=500003)
# MIDIState(time=54837, notes=[MIDINote(note=59, volume=6), MIDINote(note=62, volume=7)], tempo=500003)
# MIDIState(time=55316, notes=[MIDINote(note=52, volume=5)], tempo=500003)
# MIDIState(time=55317, notes=[MIDINote(note=56, volume=5), MIDINote(note=59, volume=7)], tempo=500003)
# MIDIState(time=55347, notes=[MIDINote(note=56, volume=5), MIDINote(note=59, volume=7)], tempo=500003)
# MIDIState(time=55827, notes=[MIDINote(note=56, volume=5), MIDINote(note=59, volume=7)], tempo=500003)
# MIDIState(time=55857, notes=[MIDINote(note=56, volume=5), MIDINote(note=59, volume=7)], tempo=500003)
# MIDIState(time=56332, notes=[MIDINote(note=56, volume=5), MIDINote(note=59, volume=7)], tempo=500003)
# MIDIState(time=56362, notes=[MIDINote(note=56, volume=5), MIDINote(note=59, volume=7)], tempo=500003)
# MIDIState(time=56837, notes=[MIDINote(note=56, volume=5), MIDINote(note=59, volume=7)], tempo=500003)
# MIDIState(time=56867, notes=[MIDINote(note=56, volume=5), MIDINote(note=59, volume=7)], tempo=500003)
# MIDIState(time=57343, notes=[MIDINote(note=52, volume=5)], tempo=500003)
# MIDIState(time=57348, notes=[MIDINote(note=57, volume=6), MIDINote(note=60, volume=7)], tempo=500003)
# MIDIState(time=57374, notes=[MIDINote(note=57, volume=6), MIDINote(note=60, volume=7)], tempo=500003)
# MIDIState(time=57890, notes=[MIDINote(note=57, volume=6), MIDINote(note=60, volume=7)], tempo=500003)
# MIDIState(time=57920, notes=[MIDINote(note=57, volume=6), MIDINote(note=60, volume=7)], tempo=500003)
# MIDIState(time=58397, notes=[MIDINote(note=52, volume=5)], tempo=500003)
# MIDIState(time=58398, notes=[MIDINote(note=60, volume=5), MIDINote(note=64, volume=7)], tempo=500003)
# MIDIState(time=58428, notes=[MIDINote(note=60, volume=5), MIDINote(note=64, volume=7)], tempo=500003)
# MIDIState(time=58903, notes=[MIDINote(note=60, volume=5), MIDINote(note=64, volume=7)], tempo=500003)
# MIDIState(time=58933, notes=[MIDINote(note=60, volume=5), MIDINote(note=64, volume=7)], tempo=500003)
# MIDIState(time=59412, notes=[MIDINote(note=52, volume=5)], tempo=500003)
# MIDIState(time=59413, notes=[MIDINote(note=64, volume=5), MIDINote(note=69, volume=7)], tempo=500003)
# MIDIState(time=59443, notes=[MIDINote(note=64, volume=5), MIDINote(note=69, volume=7)], tempo=500003)
# MIDIState(time=59923, notes=[MIDINote(note=64, volume=5), MIDINote(note=69, volume=7)], tempo=500003)
# MIDIState(time=59953, notes=[MIDINote(note=64, volume=5), MIDINote(note=69, volume=7)], tempo=500003)
# MIDIState(time=60428, notes=[MIDINote(note=64, volume=5), MIDINote(note=69, volume=7)], tempo=500003)
# MIDIState(time=60458, notes=[MIDINote(note=64, volume=5), MIDINote(note=69, volume=7)], tempo=500003)
# MIDIState(time=60933, notes=[MIDINote(note=64, volume=5), MIDINote(note=69, volume=7)], tempo=500003)
# MIDIState(time=60963, notes=[MIDINote(note=64, volume=5), MIDINote(note=69, volume=7)], tempo=500003)
# MIDIState(time=61439, notes=[MIDINote(note=52, volume=5)], tempo=500003)
# MIDIState(time=61444, notes=[MIDINote(note=64, volume=5), MIDINote(note=68, volume=7)], tempo=500003)
# MIDIState(time=61470, notes=[MIDINote(note=64, volume=5), MIDINote(note=68, volume=7)], tempo=500003)
# MIDIState(time=61986, notes=[MIDINote(note=64, volume=5), MIDINote(note=68, volume=7)], tempo=500003)
# MIDIState(time=62016, notes=[MIDINote(note=64, volume=5), MIDINote(note=68, volume=7)], tempo=500003)
# MIDIState(time=62494, notes=[MIDINote(note=64, volume=5), MIDINote(note=68, volume=7)], tempo=500003)
# MIDIState(time=62524, notes=[MIDINote(note=64, volume=5), MIDINote(note=68, volume=7)], tempo=500003)
# MIDIState(time=62999, notes=[MIDINote(note=64, volume=5), MIDINote(note=68, volume=7)], tempo=500003)
# MIDIState(time=63029, notes=[MIDINote(note=64, volume=5), MIDINote(note=68, volume=7)], tempo=500003)
# MIDIState(time=63509, notes=[MIDINote(note=64, volume=5), MIDINote(note=68, volume=7)], tempo=500003)
# MIDIState(time=63539, notes=[MIDINote(note=64, volume=5), MIDINote(note=68, volume=7)], tempo=500003)
# MIDIState(time=64019, notes=[MIDINote(note=64, volume=5), MIDINote(note=68, volume=7)], tempo=500003)
# MIDIState(time=64049, notes=[MIDINote(note=64, volume=5), MIDINote(note=68, volume=7)], tempo=500003)
# MIDIState(time=64524, notes=[MIDINote(note=64, volume=5), MIDINote(note=68, volume=7)], tempo=500003)
# MIDIState(time=64554, notes=[MIDINote(note=64, volume=5), MIDINote(note=68, volume=7)], tempo=500003)
# MIDIState(time=65029, notes=[MIDINote(note=64, volume=5), MIDINote(note=68, volume=7)], tempo=500003)
# MIDIState(time=65059, notes=[MIDINote(note=64, volume=5), MIDINote(note=68, volume=7)], tempo=500003)
# MIDIState(time=65535, notes=[MIDINote(note=52, volume=5)], tempo=500003)
# MIDIState(time=65566, notes=[], tempo=500003)

# %%
def byte_enc(byte):
    return '{0:#04x}'.format(byte)

def get_byte_str(bytes):
    return ','.join(map(byte_enc, bytes))

def varint_encode(value):
    bytes = [value & 0x7f]
    while (value > 0):
        value = value >> 7
        if (value > 0):
            bytes.append(value & 0x7f)
    bytes.reverse()
    bytes[-1] = bytes[-1] + 0x80
    return bytes

def encode_midi_note_on(time, note, volume, timer1):
    bytes = varint_encode(time)
    bytes.append((0x80 if timer1 else 0) + note)
    bytes.append(volume)
    print('%30s, //%6d %s ON, NOTE %d VOLUME %d' %
          (get_byte_str(bytes), time, 'T1' if timer1 else 'T2', note, volume))
    return bytes

def encode_midi_note_off(time, timer1):
    bytes = varint_encode(time)
    bytes.append(0x80 if timer1 else 0x00)
    print('%30s, //%6d %s OFF' %
          (get_byte_str(bytes), time, 'T1' if timer1 else 'T2'))
    return bytes    

def encode_midi_both_off(time):
    bytes = varint_encode(time)
    bytes.append(0x01)
    print('%30s, //%6d BOTH OFF' %
          (get_byte_str(bytes), time))
    return bytes        

def encode_midi_change_tempo(time,tempo):
    bytes = varint_encode(time)
    bytes.append(0x02)
    bytes += varint_encode(tempo)
    print('%30s, //%6d TEMPO > %d' %
          (get_byte_str(bytes), time,tempo))
    return bytes        
    
def encode_midi_end_program(time):
    bytes = varint_encode(time)
    bytes.append(0x04)
    print('%30s  //%6d END OF FILE' %
          (get_byte_str(bytes), time))
    return bytes

# %%
encode_midi_note_on(1056,56,5,False)
encode_midi_note_off(64,True)
encode_midi_both_off(12000)
encode_midi_change_tempo(152,141000)
encode_midi_end_program(34)
# Out:
#            0x08,0xa0,0x38,0x05, //  1056 T2 ON, NOTE 56 VOLUME 5
#                      0xc0,0x80, //    64 T1 OFF
#                 0x5d,0xe0,0x01, // 12000 BOTH OFF
#  0x01,0x98,0x02,0x08,0x4d,0xc8, //   152 TEMPO > 141000
#                      0xa2,0x04  //    34 END OF FILE
# [162, 4]

# %%
current_tempo = state_array[0].tempo
midi_data = encode_midi_change_tempo(0, current_tempo)
for i,s in enumerate(state_array):
    if i == 0:
        prev_state = MIDIState(time=0, notes=set(), tempo=current_tempo)
    else:
        prev_state = state_array[i - 1]
    time_diff = s.time - prev_state.time
    
    if s.tempo != prev_state.tempo:
        midi_data += encode_midi_change_tempo(time_diff, s.tempo)
        time_diff = 0
    
    timers_off = [False] * 2
    for timer_num in range(2):
        if len(s.notes) <= timer_num:
            if len(prev_state.notes) > timer_num:
                timers_off[timer_num] = True
        else:
            curr_note = s.notes[timer_num]
            if len(prev_state.notes) <= timer_num or prev_state.notes[timer_num] != curr_note:
                midi_data += encode_midi_note_on(time_diff,curr_note.note,curr_note.volume,timer_num==1)
                time_diff = 0
    if timers_off[0] and timers_off[1]:
        midi_data += encode_midi_both_off(time_diff)
        time_diff = 0
    elif timers_off[0]:
        midi_data += encode_midi_note_off(time_diff,False)
        time_diff = 0
    elif timers_off[1]:
        midi_data += encode_midi_note_off(time_diff,True)
        time_diff = 0
midi_data += encode_midi_end_program(0)
# Out:
#       0x80,0x02,0x1e,0x42,0xa3, //     0 TEMPO > 500003
#                 0x8a,0x47,0x06, //    10 T2 ON, NOTE 71 VOLUME 6
#                 0x80,0xcc,0x07, //     0 T1 ON, NOTE 76 VOLUME 7
#            0x03,0xdd,0x34,0x05, //   477 T2 ON, NOTE 52 VOLUME 5
#                      0x80,0x80, //     0 T1 OFF
#                 0x81,0x44,0x05, //     1 T2 ON, NOTE 68 VOLUME 5
#                 0x80,0xc7,0x07, //     0 T1 ON, NOTE 71 VOLUME 7
#            0x03,0xbc,0x28,0x05, //   444 T2 ON, NOTE 40 VOLUME 5
#                      0x9e,0x80, //    30 T1 OFF
#                 0x81,0x45,0x05, //     1 T2 ON, NOTE 69 VOLUME 5
#                 0x80,0xc8,0x07, //     0 T1 ON, NOTE 72 VOLUME 7
#            0x03,0xc1,0x34,0x05, //   449 T2 ON, NOTE 52 VOLUME 5
#                      0x9e,0x80, //    30 T1 OFF
#                 0x81,0x47,0x05, //     1 T2 ON, NOTE 71 VOLUME 5
#                 0x80,0xca,0x07, //     0 T1 ON, NOTE 74 VOLUME 7
#  0x01,0xcd,0x02,0x1e,0x64,0xf2, //   205 TEMPO > 504434
#            0x01,0xf4,0x28,0x05, //   244 T2 ON, NOTE 40 VOLUME 5
#       0x8c,0x02,0x1e,0x74,0xc0, //    12 TEMPO > 506432
#                      0x92,0x80, //    18 T1 OFF
#                 0x81,0x34,0x05, //     1 T2 ON, NOTE 52 VOLUME 5
#                 0x80,0xcc,0x06, //     0 T1 ON, NOTE 76 VOLUME 6
#                 0x01,0xca,0x80, //   202 T1 OFF
#       0x85,0x02,0x1f,0x06,0x99, //     5 TEMPO > 508697
#                 0x8b,0xca,0x06, //    11 T1 ON, NOTE 74 VOLUME 6
#                 0x01,0xf1,0x80, //   241 T1 OFF
#       0x84,0x02,0x1f,0x28,0x85, //     4 TEMPO > 513029
#                 0x8c,0x45,0x05, //    12 T2 ON, NOTE 69 VOLUME 5
#                 0x80,0xc8,0x07, //     0 T1 ON, NOTE 72 VOLUME 7
#  0x01,0xd6,0x02,0x1f,0x38,0x95, //   214 TEMPO > 515093
#            0x01,0xe6,0x28,0x05, //   230 T2 ON, NOTE 40 VOLUME 5
#       0x9a,0x02,0x1f,0x4a,0xbc, //    26 TEMPO > 517436
#                      0x84,0x80, //     4 T1 OFF
#                 0x81,0x44,0x05, //     1 T2 ON, NOTE 68 VOLUME 5
#                 0x80,0xc7,0x07, //     0 T1 ON, NOTE 71 VOLUME 7
#  0x01,0xdd,0x02,0x1f,0x5a,0xef, //   221 TEMPO > 519535
#            0x01,0xe1,0x34,0x05, //   225 T2 ON, NOTE 52 VOLUME 5
#                      0x9e,0x80, //    30 T1 OFF
#                 0x85,0x40,0x06, //     5 T2 ON, NOTE 64 VOLUME 6
#                 0x80,0xc5,0x07, //     0 T1 ON, NOTE 69 VOLUME 7
#  0x01,0xe2,0x02,0x1e,0x42,0xa3, //   226 TEMPO > 500003
#            0x03,0xdd,0x39,0x05, //   477 T2 ON, NOTE 57 VOLUME 5
#                      0x80,0x80, //     0 T1 OFF
#                 0x81,0x40,0x05, //     1 T2 ON, NOTE 64 VOLUME 5
#                 0x80,0xc5,0x07, //     0 T1 ON, NOTE 69 VOLUME 7
#            0x03,0xbc,0x2d,0x05, //   444 T2 ON, NOTE 45 VOLUME 5
#                      0x9e,0x80, //    30 T1 OFF
#                 0x81,0x45,0x05, //     1 T2 ON, NOTE 69 VOLUME 5
#                 0x80,0xc8,0x07, //     0 T1 ON, NOTE 72 VOLUME 7
#            0x03,0xc1,0x39,0x05, //   449 T2 ON, NOTE 57 VOLUME 5
#                      0x9e,0x80, //    30 T1 OFF
#                 0x81,0x48,0x05, //     1 T2 ON, NOTE 72 VOLUME 5
#                 0x80,0xcc,0x07, //     0 T1 ON, NOTE 76 VOLUME 7
#            0x03,0xda,0x39,0x05, //   474 T2 ON, NOTE 57 VOLUME 5
#                      0x80,0x80, //     0 T1 OFF
#                 0x81,0x47,0x05, //     1 T2 ON, NOTE 71 VOLUME 5
#                 0x80,0xca,0x07, //     0 T1 ON, NOTE 74 VOLUME 7
#            0x03,0xbc,0x2d,0x05, //   444 T2 ON, NOTE 45 VOLUME 5
#                      0x9e,0x80, //    30 T1 OFF
#                 0x81,0x45,0x05, //     1 T2 ON, NOTE 69 VOLUME 5
#                 0x80,0xc8,0x07, //     0 T1 ON, NOTE 72 VOLUME 7
#            0x03,0xbe,0x39,0x05, //   446 T2 ON, NOTE 57 VOLUME 5
#                      0x9e,0x80, //    30 T1 OFF
#                 0x85,0x44,0x06, //     5 T2 ON, NOTE 68 VOLUME 6
#                 0x80,0xc7,0x06, //     0 T1 ON, NOTE 71 VOLUME 6
#            0x03,0xe5,0x2c,0x05, //   485 T2 ON, NOTE 44 VOLUME 5
#                 0x9f,0x40,0x06, //    31 T2 ON, NOTE 64 VOLUME 6
#            0x03,0xbf,0x38,0x05, //   447 T2 ON, NOTE 56 VOLUME 5
#                 0x9f,0x44,0x06, //    31 T2 ON, NOTE 68 VOLUME 6
#            0x03,0xbc,0x2c,0x05, //   444 T2 ON, NOTE 44 VOLUME 5
#                      0x9e,0x80, //    30 T1 OFF
#                 0x81,0x45,0x06, //     1 T2 ON, NOTE 69 VOLUME 6
#                 0x80,0xc8,0x06, //     0 T1 ON, NOTE 72 VOLUME 6
#            0x03,0xc1,0x38,0x05, //   449 T2 ON, NOTE 56 VOLUME 5
#                      0x80,0x80, //     0 T1 OFF
#                 0x9f,0x47,0x05, //    31 T2 ON, NOTE 71 VOLUME 5
#                 0x80,0xca,0x07, //     0 T1 ON, NOTE 74 VOLUME 7
#  0x01,0xcd,0x02,0x1e,0x64,0xf2, //   205 TEMPO > 504434
#  0x02,0x80,0x02,0x1e,0x74,0xc0, //   256 TEMPO > 506432
#  0x01,0xcf,0x02,0x1f,0x06,0x99, //   207 TEMPO > 508697
#  0x02,0x80,0x02,0x1f,0x28,0x85, //   256 TEMPO > 513029
#                 0x8b,0x34,0x05, //    11 T2 ON, NOTE 52 VOLUME 5
#                      0x80,0x80, //     0 T1 OFF
#                 0x81,0x48,0x05, //     1 T2 ON, NOTE 72 VOLUME 5
#                 0x80,0xcc,0x07, //     0 T1 ON, NOTE 76 VOLUME 7
#  0x01,0xd6,0x02,0x1f,0x38,0x95, //   214 TEMPO > 515093
#  0x02,0x80,0x02,0x1f,0x4a,0xbc, //   256 TEMPO > 517436
#  0x01,0xdd,0x02,0x1f,0x5a,0xef, //   221 TEMPO > 519535
#            0x01,0xff,0x34,0x05, //   255 T2 ON, NOTE 52 VOLUME 5
#                      0x80,0x80, //     0 T1 OFF
#                 0x85,0x45,0x06, //     5 T2 ON, NOTE 69 VOLUME 6
#                 0x80,0xc8,0x07, //     0 T1 ON, NOTE 72 VOLUME 7
#  0x01,0xe2,0x02,0x1e,0x42,0xa3, //   226 TEMPO > 500003
#            0x03,0xdd,0x39,0x05, //   477 T2 ON, NOTE 57 VOLUME 5
#                      0x80,0x80, //     0 T1 OFF
#                 0x81,0x40,0x05, //     1 T2 ON, NOTE 64 VOLUME 5
#                 0x80,0xc5,0x07, //     0 T1 ON, NOTE 69 VOLUME 7
#            0x03,0xdf,0x39,0x05, //   479 T2 ON, NOTE 57 VOLUME 5
#                      0x80,0x80, //     0 T1 OFF
#                 0x81,0x40,0x05, //     1 T2 ON, NOTE 64 VOLUME 5
#                 0x80,0xc5,0x07, //     0 T1 ON, NOTE 69 VOLUME 7
#            0x03,0xdc,0x30,0x05, //   476 T2 ON, NOTE 48 VOLUME 5
#                      0x80,0x80, //     0 T1 OFF
#                 0x85,0xb2,0x05, //     5 T1 ON, NOTE 50 VOLUME 5
#                 0x9a,0x32,0x05, //    26 T2 ON, NOTE 50 VOLUME 5
#                      0x80,0x80, //     0 T1 OFF
#            0x04,0x84,0x41,0x05, //   516 T2 ON, NOTE 65 VOLUME 5
#                 0x80,0xca,0x07, //     0 T1 ON, NOTE 74 VOLUME 7
#                 0x03,0xda,0x01, //   474 BOTH OFF
#                 0x81,0x45,0x05, //     1 T2 ON, NOTE 69 VOLUME 5
#                 0x80,0xcd,0x07, //     0 T1 ON, NOTE 77 VOLUME 7
#            0x03,0xdf,0x26,0x05, //   479 T2 ON, NOTE 38 VOLUME 5
#                      0x9e,0x80, //    30 T1 OFF
#                 0x81,0x48,0x06, //     1 T2 ON, NOTE 72 VOLUME 6
#                 0x80,0xd1,0x06, //     0 T1 ON, NOTE 81 VOLUME 6
#  0x01,0xcd,0x02,0x1e,0x53,0xc2, //   205 TEMPO > 502210
#  0x02,0x80,0x02,0x1e,0x64,0xf2, //   256 TEMPO > 504434
#                 0x92,0x51,0x06, //    18 T2 ON, NOTE 81 VOLUME 6
#                      0x80,0x80, //     0 T1 OFF
#                 0x81,0x48,0x05, //     1 T2 ON, NOTE 72 VOLUME 5
#                 0x80,0xd1,0x06, //     0 T1 ON, NOTE 81 VOLUME 6
#            0x01,0xf7,0x26,0x05, //   247 T2 ON, NOTE 38 VOLUME 5
#                 0x81,0x48,0x05, //     1 T2 ON, NOTE 72 VOLUME 5
#  0x01,0xf5,0x02,0x1e,0x74,0xc0, //   245 TEMPO > 506432
#                 0x8b,0x26,0x05, //    11 T2 ON, NOTE 38 VOLUME 5
#                 0x80,0xc8,0x05, //     0 T1 ON, NOTE 72 VOLUME 5
#                 0x81,0x48,0x05, //     1 T2 ON, NOTE 72 VOLUME 5
#                 0x80,0xcf,0x07, //     0 T1 ON, NOTE 79 VOLUME 7
#                 0x8e,0x47,0x05, //    14 T2 ON, NOTE 71 VOLUME 5
#            0x03,0xbc,0x2d,0x05, //   444 T2 ON, NOTE 45 VOLUME 5
#       0x9a,0x02,0x1f,0x06,0x99, //    26 TEMPO > 508697
#                      0x84,0x80, //     4 T1 OFF
#                 0x81,0x45,0x05, //     1 T2 ON, NOTE 69 VOLUME 5
#                 0x80,0xcd,0x07, //     0 T1 ON, NOTE 77 VOLUME 7
#  0x01,0xdd,0x02,0x1f,0x16,0x86, //   221 TEMPO > 510726
#            0x01,0xe1,0x29,0x05, //   225 T2 ON, NOTE 41 VOLUME 5
#                      0x9e,0x80, //    30 T1 OFF
#       0x81,0x02,0x1e,0x42,0xa3, //     1 TEMPO > 500003
#                 0x84,0x43,0x06, //     4 T2 ON, NOTE 67 VOLUME 6
#                 0x80,0xcc,0x07, //     0 T1 ON, NOTE 76 VOLUME 7
#                 0x03,0xda,0x01, //   474 BOTH OFF
#                 0x81,0x40,0x05, //     1 T2 ON, NOTE 64 VOLUME 5
#                 0x80,0xc8,0x07, //     0 T1 ON, NOTE 72 VOLUME 7
#            0x03,0xdf,0x30,0x05, //   479 T2 ON, NOTE 48 VOLUME 5
#                      0x9e,0x80, //    30 T1 OFF
#                 0x81,0x43,0x06, //     1 T2 ON, NOTE 67 VOLUME 6
#                 0x80,0xcc,0x06, //     0 T1 ON, NOTE 76 VOLUME 6
#            0x03,0xc1,0x24,0x05, //   449 T2 ON, NOTE 36 VOLUME 5
#                 0x9f,0x45,0x06, //    31 T2 ON, NOTE 69 VOLUME 6
#            0x01,0xca,0x2b,0x05, //   202 T2 ON, NOTE 43 VOLUME 5
#                 0x90,0x43,0x06, //    16 T2 ON, NOTE 67 VOLUME 6
#            0x01,0xf1,0x2b,0x05, //   241 T2 ON, NOTE 43 VOLUME 5
#                      0x8f,0x80, //    15 T1 OFF
#                 0x81,0x41,0x05, //     1 T2 ON, NOTE 65 VOLUME 5
#                 0x80,0xca,0x07, //     0 T1 ON, NOTE 74 VOLUME 7
#            0x03,0xbc,0x4a,0x07, //   444 T2 ON, NOTE 74 VOLUME 7
#                      0x80,0x80, //     0 T1 OFF
#                      0x9e,0x00, //    30 T2 OFF
#                 0x81,0x40,0x05, //     1 T2 ON, NOTE 64 VOLUME 5
#                 0x80,0xc8,0x07, //     0 T1 ON, NOTE 72 VOLUME 7
#            0x03,0xdc,0x2b,0x05, //   476 T2 ON, NOTE 43 VOLUME 5
#                      0x9e,0x80, //    30 T1 OFF
#                 0x85,0x44,0x06, //     5 T2 ON, NOTE 68 VOLUME 6
#                 0x80,0xc7,0x06, //     0 T1 ON, NOTE 71 VOLUME 6
#            0x03,0xe5,0x2f,0x05, //   485 T2 ON, NOTE 47 VOLUME 5
#                 0x9f,0x40,0x06, //    31 T2 ON, NOTE 64 VOLUME 6
#            0x03,0xbf,0x3b,0x05, //   447 T2 ON, NOTE 59 VOLUME 5
#                      0x9e,0x80, //    30 T1 OFF
#                 0x81,0x44,0x05, //     1 T2 ON, NOTE 68 VOLUME 5
#                 0x80,0xc7,0x07, //     0 T1 ON, NOTE 71 VOLUME 7
#            0x03,0xbc,0x47,0x07, //   444 T2 ON, NOTE 71 VOLUME 7
#                      0x80,0x80, //     0 T1 OFF
#                      0x9e,0x00, //    30 T2 OFF
#                 0x81,0x45,0x05, //     1 T2 ON, NOTE 69 VOLUME 5
#                 0x80,0xc8,0x07, //     0 T1 ON, NOTE 72 VOLUME 7
#            0x03,0xdf,0x3b,0x05, //   479 T2 ON, NOTE 59 VOLUME 5
#                      0x9e,0x80, //    30 T1 OFF
#                 0x81,0x47,0x06, //     1 T2 ON, NOTE 71 VOLUME 6
#                 0x80,0xca,0x06, //     0 T1 ON, NOTE 74 VOLUME 6
#            0x03,0xc1,0x4a,0x06, //   449 T2 ON, NOTE 74 VOLUME 6
#                      0x80,0x80, //     0 T1 OFF
#                 0x9f,0x44,0x06, //    31 T2 ON, NOTE 68 VOLUME 6
#                 0x80,0xca,0x06, //     0 T1 ON, NOTE 74 VOLUME 6
#            0x03,0xda,0x34,0x05, //   474 T2 ON, NOTE 52 VOLUME 5
#                      0x9e,0x80, //    30 T1 OFF
#                 0x81,0x48,0x06, //     1 T2 ON, NOTE 72 VOLUME 6
#                 0x80,0xcc,0x06, //     0 T1 ON, NOTE 76 VOLUME 6
#            0x03,0xbc,0x4c,0x06, //   444 T2 ON, NOTE 76 VOLUME 6
#                      0x80,0x80, //     0 T1 OFF
#                 0x9f,0x44,0x06, //    31 T2 ON, NOTE 68 VOLUME 6
#                 0x80,0xcc,0x06, //     0 T1 ON, NOTE 76 VOLUME 6
#            0x03,0xdc,0x38,0x05, //   476 T2 ON, NOTE 56 VOLUME 5
#                      0x9e,0x80, //    30 T1 OFF
#                 0x85,0x45,0x06, //     5 T2 ON, NOTE 69 VOLUME 6
#                 0x80,0xc8,0x06, //     0 T1 ON, NOTE 72 VOLUME 6
#            0x03,0xe5,0x2d,0x05, //   485 T2 ON, NOTE 45 VOLUME 5
#                 0x9f,0x40,0x06, //    31 T2 ON, NOTE 64 VOLUME 6
#            0x03,0xbf,0x34,0x05, //   447 T2 ON, NOTE 52 VOLUME 5
#                      0x9e,0x80, //    30 T1 OFF
#                 0x81,0x40,0x05, //     1 T2 ON, NOTE 64 VOLUME 5
#                 0x80,0xc5,0x06, //     0 T1 ON, NOTE 69 VOLUME 6
#            0x03,0xdf,0x34,0x05, //   479 T2 ON, NOTE 52 VOLUME 5
#                      0x80,0x80, //     0 T1 OFF
#                 0x81,0x40,0x05, //     1 T2 ON, NOTE 64 VOLUME 5
#                 0x80,0xc5,0x07, //     0 T1 ON, NOTE 69 VOLUME 7
#                 0x07,0xd8,0x01, //   984 BOTH OFF
#            0x07,0xf9,0x3c,0x06, //  1017 T2 ON, NOTE 60 VOLUME 6
#                 0x80,0xc0,0x07, //     0 T1 ON, NOTE 64 VOLUME 7
#            0x03,0xdf,0x34,0x05, //   479 T2 ON, NOTE 52 VOLUME 5
#                      0x80,0x80, //     0 T1 OFF
#                 0x81,0x39,0x05, //     1 T2 ON, NOTE 57 VOLUME 5
#                 0x80,0xbc,0x07, //     0 T1 ON, NOTE 60 VOLUME 7
#            0x03,0xdc,0x34,0x05, //   476 T2 ON, NOTE 52 VOLUME 5
#                      0x80,0x80, //     0 T1 OFF
#                 0x85,0x3b,0x06, //     5 T2 ON, NOTE 59 VOLUME 6
#                 0x80,0xbe,0x07, //     0 T1 ON, NOTE 62 VOLUME 7
#            0x03,0xdf,0x34,0x05, //   479 T2 ON, NOTE 52 VOLUME 5
#                      0x80,0x80, //     0 T1 OFF
#                 0x81,0x38,0x05, //     1 T2 ON, NOTE 56 VOLUME 5
#                 0x80,0xbb,0x07, //     0 T1 ON, NOTE 59 VOLUME 7
#  0x01,0xcd,0x02,0x1e,0x64,0xf2, //   205 TEMPO > 504434
#  0x02,0x80,0x02,0x1e,0x74,0xc0, //   256 TEMPO > 506432
#  0x01,0xcf,0x02,0x1f,0x06,0x99, //   207 TEMPO > 508697
#  0x02,0x80,0x02,0x1f,0x28,0x85, //   256 TEMPO > 513029
#  0x01,0xd6,0x02,0x1f,0x38,0x95, //   214 TEMPO > 515093
#  0x02,0x80,0x02,0x1f,0x4a,0xbc, //   256 TEMPO > 517436
#  0x01,0xdd,0x02,0x1f,0x5a,0xef, //   221 TEMPO > 519535
#            0x01,0xff,0x34,0x05, //   255 T2 ON, NOTE 52 VOLUME 5
#                      0x80,0x80, //     0 T1 OFF
#                 0x85,0x39,0x06, //     5 T2 ON, NOTE 57 VOLUME 6
#                 0x80,0xbc,0x07, //     0 T1 ON, NOTE 60 VOLUME 7
#  0x01,0xe2,0x02,0x1e,0x42,0xa3, //   226 TEMPO > 500003
#            0x03,0xdf,0x34,0x05, //   479 T2 ON, NOTE 52 VOLUME 5
#                      0x80,0x80, //     0 T1 OFF
#                 0x81,0xb9,0x07, //     1 T1 ON, NOTE 57 VOLUME 7
#                 0x9e,0x2d,0x05, //    30 T2 ON, NOTE 45 VOLUME 5
#            0x03,0xe0,0x34,0x05, //   480 T2 ON, NOTE 52 VOLUME 5
#                 0x9e,0x2d,0x05, //    30 T2 ON, NOTE 45 VOLUME 5
#            0x03,0xdb,0x34,0x05, //   475 T2 ON, NOTE 52 VOLUME 5
#                 0x03,0xdc,0x01, //   476 BOTH OFF
#                 0x85,0x34,0x06, //     5 T2 ON, NOTE 52 VOLUME 6
#                 0x80,0xb8,0x07, //     0 T1 ON, NOTE 56 VOLUME 7
#                 0x9a,0x2c,0x05, //    26 T2 ON, NOTE 44 VOLUME 5
#            0x04,0x84,0x34,0x05, //   516 T2 ON, NOTE 52 VOLUME 5
#                 0x9e,0x2c,0x05, //    30 T2 ON, NOTE 44 VOLUME 5
#            0x03,0xdb,0x34,0x05, //   475 T2 ON, NOTE 52 VOLUME 5
#                 0x03,0xdf,0x01, //   479 BOTH OFF
#                 0x81,0x38,0x05, //     1 T2 ON, NOTE 56 VOLUME 5
#                 0x80,0xbb,0x07, //     0 T1 ON, NOTE 59 VOLUME 7
#  0x01,0xeb,0x02,0x1e,0x64,0xf2, //   235 TEMPO > 504434
#  0x02,0x80,0x02,0x1e,0x74,0xc0, //   256 TEMPO > 506432
#  0x01,0xcf,0x02,0x1f,0x06,0x99, //   207 TEMPO > 508697
#  0x02,0x80,0x02,0x1f,0x28,0x85, //   256 TEMPO > 513029
#  0x01,0xd6,0x02,0x1f,0x38,0x95, //   214 TEMPO > 515093
#  0x02,0x80,0x02,0x1f,0x4a,0xbc, //   256 TEMPO > 517436
#  0x01,0xdd,0x02,0x1f,0x5a,0xef, //   221 TEMPO > 519535
#            0x01,0xff,0x34,0x05, //   255 T2 ON, NOTE 52 VOLUME 5
#                      0x80,0x80, //     0 T1 OFF
#                 0x85,0x3c,0x06, //     5 T2 ON, NOTE 60 VOLUME 6
#                 0x80,0xc0,0x07, //     0 T1 ON, NOTE 64 VOLUME 7
#  0x01,0xe2,0x02,0x1e,0x42,0xa3, //   226 TEMPO > 500003
#            0x03,0xdf,0x34,0x05, //   479 T2 ON, NOTE 52 VOLUME 5
#                      0x80,0x80, //     0 T1 OFF
#                 0x81,0x39,0x05, //     1 T2 ON, NOTE 57 VOLUME 5
#                 0x80,0xbc,0x07, //     0 T1 ON, NOTE 60 VOLUME 7
#            0x03,0xdc,0x34,0x05, //   476 T2 ON, NOTE 52 VOLUME 5
#                      0x80,0x80, //     0 T1 OFF
#                 0x85,0x3b,0x06, //     5 T2 ON, NOTE 59 VOLUME 6
#                 0x80,0xbe,0x07, //     0 T1 ON, NOTE 62 VOLUME 7
#            0x03,0xdf,0x34,0x05, //   479 T2 ON, NOTE 52 VOLUME 5
#                      0x80,0x80, //     0 T1 OFF
#                 0x81,0x38,0x05, //     1 T2 ON, NOTE 56 VOLUME 5
#                 0x80,0xbb,0x07, //     0 T1 ON, NOTE 59 VOLUME 7
#            0x03,0xdc,0x34,0x05, //   476 T2 ON, NOTE 52 VOLUME 5
#                      0x80,0x80, //     0 T1 OFF
#                 0x85,0x39,0x06, //     5 T2 ON, NOTE 57 VOLUME 6
#                 0x80,0xbc,0x07, //     0 T1 ON, NOTE 60 VOLUME 7
#            0x03,0xdd,0x34,0x05, //   477 T2 ON, NOTE 52 VOLUME 5
#                      0x80,0x80, //     0 T1 OFF
#                 0x81,0x3c,0x05, //     1 T2 ON, NOTE 60 VOLUME 5
#                 0x80,0xc0,0x07, //     0 T1 ON, NOTE 64 VOLUME 7
#            0x03,0xdf,0x34,0x05, //   479 T2 ON, NOTE 52 VOLUME 5
#                      0x80,0x80, //     0 T1 OFF
#                 0x81,0x40,0x05, //     1 T2 ON, NOTE 64 VOLUME 5
#                 0x80,0xc5,0x07, //     0 T1 ON, NOTE 69 VOLUME 7
#            0x03,0xdc,0x34,0x05, //   476 T2 ON, NOTE 52 VOLUME 5
#                      0x80,0x80, //     0 T1 OFF
#                 0x85,0x40,0x05, //     5 T2 ON, NOTE 64 VOLUME 5
#                 0x80,0xc4,0x07, //     0 T1 ON, NOTE 68 VOLUME 7
#            0x03,0xdc,0x34,0x05, //   476 T2 ON, NOTE 52 VOLUME 5
#                      0x80,0x80, //     0 T1 OFF
#                      0x9f,0x00, //    31 T2 OFF
#                      0x80,0x04  //     0 END OF FILE

# %%
get_byte_str(midi_data)
# Out:
# ' ...

# %%
for msg in mid.tracks[1]:
    print(msg)
# Out:
# <meta message device_name name='SmartMusic SoftSynth 1' time=0>
# <meta message track_name name='Acoustic Grand Piano' time=0>
# program_change channel=0 program=0 time=0
# control_change channel=0 control=7 value=101 time=0
# control_change channel=0 control=10 value=64 time=0
# control_change channel=0 control=7 value=110 time=0
# control_change channel=0 control=100 value=0 time=3
# control_change channel=0 control=101 value=0 time=0
# control_change channel=0 control=6 value=12 time=1
# control_change channel=0 control=38 value=0 time=1
# note_on channel=0 note=71 velocity=61 time=5
# note_on channel=0 note=76 velocity=75 time=0
# note_off channel=0 note=71 velocity=0 time=1043
# note_off channel=0 note=76 velocity=0 time=0
# note_on channel=0 note=68 velocity=57 time=1
# note_on channel=0 note=71 velocity=71 time=0
# note_off channel=0 note=68 velocity=0 time=474
# note_off channel=0 note=71 velocity=0 time=30
# note_on channel=0 note=69 velocity=56 time=1
# note_on channel=0 note=72 velocity=70 time=0
# note_off channel=0 note=69 velocity=0 time=479
# note_off channel=0 note=72 velocity=0 time=30
# note_on channel=0 note=71 velocity=59 time=1
# note_on channel=0 note=74 velocity=73 time=0
# note_off channel=0 note=71 velocity=0 time=479
# note_off channel=0 note=74 velocity=0 time=30
# note_on channel=0 note=76 velocity=64 time=1
# note_off channel=0 note=76 velocity=0 time=232
# note_on channel=0 note=74 velocity=64 time=16
# note_off channel=0 note=74 velocity=0 time=241
# note_on channel=0 note=69 velocity=57 time=16
# note_on channel=0 note=72 velocity=71 time=0
# note_off channel=0 note=69 velocity=0 time=474
# note_off channel=0 note=72 velocity=0 time=30
# note_on channel=0 note=68 velocity=56 time=1
# note_on channel=0 note=71 velocity=70 time=0
# note_off channel=0 note=68 velocity=0 time=476
# note_off channel=0 note=71 velocity=0 time=30
# note_on channel=0 note=64 velocity=61 time=5
# note_on channel=0 note=69 velocity=75 time=0
# note_off channel=0 note=64 velocity=0 time=1049
# note_off channel=0 note=69 velocity=0 time=0
# note_on channel=0 note=64 velocity=57 time=1
# note_on channel=0 note=69 velocity=71 time=0
# note_off channel=0 note=64 velocity=0 time=474
# note_off channel=0 note=69 velocity=0 time=30
# note_on channel=0 note=69 velocity=56 time=1
# note_on channel=0 note=72 velocity=70 time=0
# note_off channel=0 note=69 velocity=0 time=479
# note_off channel=0 note=72 velocity=0 time=30
# note_on channel=0 note=72 velocity=59 time=1
# note_on channel=0 note=76 velocity=73 time=0
# note_off channel=0 note=72 velocity=0 time=1014
# note_off channel=0 note=76 velocity=0 time=0
# note_on channel=0 note=71 velocity=57 time=1
# note_on channel=0 note=74 velocity=71 time=0
# note_off channel=0 note=71 velocity=0 time=474
# note_off channel=0 note=74 velocity=0 time=30
# note_on channel=0 note=69 velocity=56 time=1
# note_on channel=0 note=72 velocity=70 time=0
# note_off channel=0 note=69 velocity=0 time=476
# note_off channel=0 note=72 velocity=0 time=30
# note_on channel=0 note=71 velocity=69 time=5
# note_on channel=0 note=68 velocity=69 time=0
# note_off channel=0 note=68 velocity=0 time=511
# note_on channel=0 note=64 velocity=64 time=31
# note_off channel=0 note=64 velocity=0 time=477
# note_on channel=0 note=68 velocity=65 time=31
# note_off channel=0 note=68 velocity=0 time=474
# note_off channel=0 note=71 velocity=0 time=30
# note_on channel=0 note=72 velocity=64 time=1
# note_on channel=0 note=69 velocity=64 time=0
# note_off channel=0 note=72 velocity=0 time=479
# note_off channel=0 note=69 velocity=0 time=0
# note_on channel=0 note=71 velocity=59 time=31
# note_on channel=0 note=74 velocity=73 time=0
# note_off channel=0 note=71 velocity=0 time=1014
# note_off channel=0 note=74 velocity=0 time=0
# note_on channel=0 note=72 velocity=57 time=1
# note_on channel=0 note=76 velocity=71 time=0
# note_off channel=0 note=72 velocity=0 time=1011
# note_off channel=0 note=76 velocity=0 time=0
# note_on channel=0 note=69 velocity=61 time=5
# note_on channel=0 note=72 velocity=75 time=0
# note_off channel=0 note=69 velocity=0 time=1049
# note_off channel=0 note=72 velocity=0 time=0
# note_on channel=0 note=64 velocity=57 time=1
# note_on channel=0 note=69 velocity=71 time=0
# note_off channel=0 note=64 velocity=0 time=1014
# note_off channel=0 note=69 velocity=0 time=0
# note_on channel=0 note=64 velocity=59 time=1
# note_on channel=0 note=69 velocity=73 time=0
# note_off channel=0 note=64 velocity=0 time=2026
# note_off channel=0 note=69 velocity=0 time=0
# note_on channel=0 note=65 velocity=56 time=547
# note_on channel=0 note=74 velocity=70 time=0
# note_off channel=0 note=65 velocity=0 time=1012
# note_off channel=0 note=74 velocity=0 time=0
# note_on channel=0 note=69 velocity=56 time=1
# note_on channel=0 note=77 velocity=70 time=0
# note_off channel=0 note=69 velocity=0 time=479
# note_off channel=0 note=77 velocity=0 time=30
# note_on channel=0 note=81 velocity=67 time=1
# note_on channel=0 note=72 velocity=67 time=0
# note_off channel=0 note=72 velocity=0 time=509
# note_on channel=0 note=72 velocity=52 time=1
# note_off channel=0 note=72 velocity=0 time=247
# note_on channel=0 note=72 velocity=52 time=1
# note_off channel=0 note=81 velocity=0 time=256
# note_on channel=0 note=71 velocity=57 time=1
# note_on channel=0 note=79 velocity=71 time=0
# note_off channel=0 note=72 velocity=0 time=14
# note_off channel=0 note=71 velocity=0 time=460
# note_off channel=0 note=79 velocity=0 time=30
# note_on channel=0 note=69 velocity=56 time=1
# note_on channel=0 note=77 velocity=70 time=0
# note_off channel=0 note=69 velocity=0 time=476
# note_off channel=0 note=77 velocity=0 time=30
# note_on channel=0 note=67 velocity=61 time=5
# note_on channel=0 note=76 velocity=75 time=0
# note_off channel=0 note=67 velocity=0 time=1554
# note_off channel=0 note=76 velocity=0 time=0
# note_on channel=0 note=64 velocity=56 time=1
# note_on channel=0 note=72 velocity=70 time=0
# note_off channel=0 note=64 velocity=0 time=479
# note_off channel=0 note=72 velocity=0 time=30
# note_on channel=0 note=76 velocity=67 time=1
# note_on channel=0 note=67 velocity=67 time=0
# note_off channel=0 note=67 velocity=0 time=479
# note_on channel=0 note=69 velocity=64 time=31
# note_off channel=0 note=69 velocity=0 time=232
# note_on channel=0 note=67 velocity=64 time=16
# note_off channel=0 note=67 velocity=0 time=241
# note_off channel=0 note=76 velocity=0 time=15
# note_on channel=0 note=65 velocity=57 time=1
# note_on channel=0 note=74 velocity=71 time=0
# note_off channel=0 note=65 velocity=0 time=474
# note_off channel=0 note=74 velocity=0 time=30
# note_on channel=0 note=64 velocity=56 time=1
# note_on channel=0 note=72 velocity=70 time=0
# note_off channel=0 note=64 velocity=0 time=476
# note_off channel=0 note=72 velocity=0 time=30
# note_on channel=0 note=71 velocity=69 time=5
# note_on channel=0 note=68 velocity=69 time=0
# note_off channel=0 note=68 velocity=0 time=511
# note_on channel=0 note=64 velocity=64 time=31
# note_off channel=0 note=64 velocity=0 time=477
# note_off channel=0 note=71 velocity=0 time=30
# note_on channel=0 note=68 velocity=57 time=1
# note_on channel=0 note=71 velocity=71 time=0
# note_off channel=0 note=68 velocity=0 time=474
# note_off channel=0 note=71 velocity=0 time=30
# note_on channel=0 note=69 velocity=56 time=1
# note_on channel=0 note=72 velocity=70 time=0
# note_off channel=0 note=69 velocity=0 time=479
# note_off channel=0 note=72 velocity=0 time=30
# note_on channel=0 note=74 velocity=67 time=1
# note_on channel=0 note=71 velocity=67 time=0
# note_off channel=0 note=71 velocity=0 time=479
# note_on channel=0 note=68 velocity=64 time=31
# note_off channel=0 note=68 velocity=0 time=474
# note_off channel=0 note=74 velocity=0 time=30
# note_on channel=0 note=76 velocity=65 time=1
# note_on channel=0 note=72 velocity=65 time=0
# note_off channel=0 note=72 velocity=0 time=474
# note_on channel=0 note=68 velocity=64 time=31
# note_off channel=0 note=68 velocity=0 time=476
# note_off channel=0 note=76 velocity=0 time=30
# note_on channel=0 note=72 velocity=69 time=5
# note_on channel=0 note=69 velocity=69 time=0
# note_off channel=0 note=69 velocity=0 time=511
# note_on channel=0 note=64 velocity=64 time=31
# note_off channel=0 note=64 velocity=0 time=477
# note_off channel=0 note=72 velocity=0 time=30
# note_on channel=0 note=64 velocity=57 time=1
# note_on channel=0 note=69 velocity=67 time=0
# note_off channel=0 note=64 velocity=0 time=1014
# note_off channel=0 note=69 velocity=0 time=0
# note_on channel=0 note=64 velocity=59 time=1
# note_on channel=0 note=69 velocity=73 time=0
# note_off channel=0 note=64 velocity=0 time=1014
# note_off channel=0 note=69 velocity=0 time=0
# note_on channel=0 note=60 velocity=61 time=1017
# note_on channel=0 note=64 velocity=75 time=0
# note_off channel=0 note=60 velocity=0 time=2064
# note_off channel=0 note=64 velocity=0 time=0
# note_on channel=0 note=57 velocity=59 time=1
# note_on channel=0 note=60 velocity=73 time=0
# note_off channel=0 note=57 velocity=0 time=2026
# note_off channel=0 note=60 velocity=0 time=0
# note_on channel=0 note=59 velocity=61 time=5
# note_on channel=0 note=62 velocity=75 time=0
# note_off channel=0 note=59 velocity=0 time=2064
# note_off channel=0 note=62 velocity=0 time=0
# note_on channel=0 note=56 velocity=59 time=1
# note_on channel=0 note=59 velocity=73 time=0
# note_off channel=0 note=56 velocity=0 time=2026
# note_off channel=0 note=59 velocity=0 time=0
# note_on channel=0 note=57 velocity=61 time=5
# note_on channel=0 note=60 velocity=75 time=0
# note_off channel=0 note=57 velocity=0 time=2064
# note_off channel=0 note=60 velocity=0 time=0
# note_on channel=0 note=52 velocity=59 time=1
# note_on channel=0 note=57 velocity=73 time=0
# note_off channel=0 note=52 velocity=0 time=2026
# note_off channel=0 note=57 velocity=0 time=0
# note_on channel=0 note=52 velocity=61 time=5
# note_on channel=0 note=56 velocity=75 time=0
# note_off channel=0 note=52 velocity=0 time=2064
# note_off channel=0 note=56 velocity=0 time=0
# note_on channel=0 note=56 velocity=59 time=1
# note_on channel=0 note=59 velocity=73 time=0
# note_off channel=0 note=56 velocity=0 time=2026
# note_off channel=0 note=59 velocity=0 time=0
# note_on channel=0 note=60 velocity=61 time=5
# note_on channel=0 note=64 velocity=75 time=0
# note_off channel=0 note=60 velocity=0 time=2064
# note_off channel=0 note=64 velocity=0 time=0
# note_on channel=0 note=57 velocity=59 time=1
# note_on channel=0 note=60 velocity=73 time=0
# note_off channel=0 note=57 velocity=0 time=2026
# note_off channel=0 note=60 velocity=0 time=0
# note_on channel=0 note=59 velocity=61 time=5
# note_on channel=0 note=62 velocity=75 time=0
# note_off channel=0 note=59 velocity=0 time=2064
# note_off channel=0 note=62 velocity=0 time=0
# note_on channel=0 note=56 velocity=59 time=1
# note_on channel=0 note=59 velocity=73 time=0
# note_off channel=0 note=56 velocity=0 time=2026
# note_off channel=0 note=59 velocity=0 time=0
# note_on channel=0 note=57 velocity=61 time=5
# note_on channel=0 note=60 velocity=75 time=0
# note_off channel=0 note=57 velocity=0 time=1049
# note_off channel=0 note=60 velocity=0 time=0
# note_on channel=0 note=60 velocity=57 time=1
# note_on channel=0 note=64 velocity=71 time=0
# note_off channel=0 note=60 velocity=0 time=1014
# note_off channel=0 note=64 velocity=0 time=0
# note_on channel=0 note=64 velocity=59 time=1
# note_on channel=0 note=69 velocity=73 time=0
# note_off channel=0 note=64 velocity=0 time=2026
# note_off channel=0 note=69 velocity=0 time=0
# note_on channel=0 note=64 velocity=56 time=5
# note_on channel=0 note=68 velocity=70 time=0
# note_off channel=0 note=64 velocity=0 time=4091
# note_off channel=0 note=68 velocity=0 time=0
# <meta message end_of_track time=31>

# %%
MIDI_TICKS_PER_BEAT = mid.ticks_per_beat
ts_msg = next(m for m in mid if m.type == 'time_signature')
MIDI_TS_NUM = ts_msg.numerator
MIDI_TS_DEN = ts_msg.denominator

# %%
OUTPUT_TICKS_PER_BAR = 1024
MIDI_TICKS_PER_OUTPUT_TICK = (MIDI_TICKS_PER_BEAT * 4) / OUTPUT_TICKS_PER_BAR
state_array_condensed = deepcopy(state_array)

# First, remove messages that occur within the same output tick
i = 1
prev_tick = int(state_array_condensed[0].time / MIDI_TICKS_PER_OUTPUT_TICK)
while i < len(state_array_condensed):
    output_tick = int(state_array_condensed[i].time / MIDI_TICKS_PER_OUTPUT_TICK)
    if output_tick <= prev_tick:
        state_array_condensed.pop(i - 1)
    else:
        prev_tick = output_tick
        i += 1
        
# Now remove all but the highest two notes
def drop_low_notes(s):
    hi_notes = sorted(s.notes, key=lambda n:n.note)[-2:]
    return MIDIState(s.time, hi_notes, s.tempo)
state_array_condensed = list(map(drop_low_notes, state_array_condensed))

for i, s in enumerate(state_array_condensed):
    if i > 0:
        prev_s = state_array_condensed[i - 1]
    else:
        prev_s = MIDIState(0, [MIDINote(0,0), MIDINote(0,0)], 0)
    note_num = len(s.notes)
    new_notes = s.notes + prev_s.notes[note_num:]
    new_notes = list(map(lambda n:MIDINote(n.note, int(n.volume/10)), new_notes))
    state_array_condensed[i] = MIDIState(s.time, new_notes, s.tempo)

# %%
MIDI_TICKS_PER_OUTPUT_TICK
# Out:
# 4.0

# %%
sorted(state_array[1].notes, key=lambda n:n.note)[-2:]
# Out:
# [MIDINote(note=71, volume=6), MIDINote(note=76, volume=7)]

# %%
state_array_condensed
# Out:
# [MIDIState(time=0, notes=[MIDINote(note=0, volume=0), MIDINote(note=0, volume=0)], tempo=500003),
#  MIDIState(time=10, notes=[MIDINote(note=71, volume=0), MIDINote(note=76, volume=0)], tempo=500003),
#  MIDIState(time=546, notes=[MIDINote(note=71, volume=0), MIDINote(note=76, volume=0)], tempo=500003),
#  MIDIState(time=576, notes=[MIDINote(note=71, volume=0), MIDINote(note=76, volume=0)], tempo=500003),
#  MIDIState(time=1054, notes=[MIDINote(note=68, volume=0), MIDINote(note=71, volume=0)], tempo=500003),
#  MIDIState(time=1084, notes=[MIDINote(note=68, volume=0), MIDINote(note=71, volume=0)], tempo=500003),
#  MIDIState(time=1528, notes=[MIDINote(note=40, volume=0), MIDINote(note=71, volume=0)], tempo=500003),
#  MIDIState(time=1559, notes=[MIDINote(note=69, volume=0), MIDINote(note=72, volume=0)], tempo=500003),
#  MIDIState(time=1589, notes=[MIDINote(note=69, volume=0), MIDINote(note=72, volume=0)], tempo=500003),
#  MIDIState(time=2038, notes=[MIDINote(note=52, volume=0), MIDINote(note=72, volume=0)], tempo=500003),
#  MIDIState(time=2069, notes=[MIDINote(note=71, volume=0), MIDINote(note=74, volume=0)], tempo=500003),
#  MIDIState(time=2099, notes=[MIDINote(note=71, volume=0), MIDINote(note=74, volume=0)], tempo=500003),
#  MIDIState(time=2304, notes=[MIDINote(note=71, volume=0), MIDINote(note=74, volume=0)], tempo=504434),
#  MIDIState(time=2548, notes=[MIDINote(note=40, volume=0), MIDINote(note=74, volume=0)], tempo=504434),
#  MIDIState(time=2560, notes=[MIDINote(note=40, volume=0), MIDINote(note=74, volume=0)], tempo=506432),
#  MIDIState(time=2579, notes=[MIDINote(note=52, volume=0), MIDINote(note=76, volume=0)], tempo=506432),
#  MIDIState(time=2609, notes=[MIDINote(note=52, volume=0), MIDINote(note=76, volume=0)], tempo=506432),
#  MIDIState(time=2811, notes=[MIDINote(note=52, volume=0), MIDINote(note=76, volume=0)], tempo=506432),
#  MIDIState(time=2816, notes=[MIDINote(note=52, volume=0), MIDINote(note=76, volume=0)], tempo=508697),
#  MIDIState(time=2827, notes=[MIDINote(note=52, volume=0), MIDINote(note=74, volume=0)], tempo=508697),
#  MIDIState(time=3068, notes=[MIDINote(note=52, volume=0), MIDINote(note=74, volume=0)], tempo=508697),
#  MIDIState(time=3072, notes=[MIDINote(note=52, volume=0), MIDINote(note=74, volume=0)], tempo=513029),
#  MIDIState(time=3084, notes=[MIDINote(note=69, volume=0), MIDINote(note=72, volume=0)], tempo=513029),
#  MIDIState(time=3114, notes=[MIDINote(note=69, volume=0), MIDINote(note=72, volume=0)], tempo=513029),
#  MIDIState(time=3328, notes=[MIDINote(note=69, volume=0), MIDINote(note=72, volume=0)], tempo=515093),
#  MIDIState(time=3558, notes=[MIDINote(note=40, volume=0), MIDINote(note=72, volume=0)], tempo=515093),
#  MIDIState(time=3584, notes=[MIDINote(note=40, volume=0), MIDINote(note=72, volume=0)], tempo=517436),
#  MIDIState(time=3589, notes=[MIDINote(note=68, volume=0), MIDINote(note=71, volume=0)], tempo=517436),
#  MIDIState(time=3619, notes=[MIDINote(note=68, volume=0), MIDINote(note=71, volume=0)], tempo=517436),
#  MIDIState(time=3840, notes=[MIDINote(note=68, volume=0), MIDINote(note=71, volume=0)], tempo=519535),
#  MIDIState(time=4065, notes=[MIDINote(note=52, volume=0), MIDINote(note=71, volume=0)], tempo=519535),
#  MIDIState(time=4095, notes=[MIDINote(note=52, volume=0), MIDINote(note=71, volume=0)], tempo=519535),
#  MIDIState(time=4100, notes=[MIDINote(note=64, volume=0), MIDINote(note=69, volume=0)], tempo=519535),
#  MIDIState(time=4126, notes=[MIDINote(note=64, volume=0), MIDINote(note=69, volume=0)], tempo=519535),
#  MIDIState(time=4352, notes=[MIDINote(note=64, volume=0), MIDINote(note=69, volume=0)], tempo=500003),
#  MIDIState(time=4642, notes=[MIDINote(note=64, volume=0), MIDINote(note=69, volume=0)], tempo=500003),
#  MIDIState(time=4672, notes=[MIDINote(note=64, volume=0), MIDINote(note=69, volume=0)], tempo=500003),
#  MIDIState(time=5150, notes=[MIDINote(note=64, volume=0), MIDINote(note=69, volume=0)], tempo=500003),
#  MIDIState(time=5180, notes=[MIDINote(note=64, volume=0), MIDINote(note=69, volume=0)], tempo=500003),
#  MIDIState(time=5624, notes=[MIDINote(note=45, volume=0), MIDINote(note=69, volume=0)], tempo=500003),
#  MIDIState(time=5655, notes=[MIDINote(note=69, volume=0), MIDINote(note=72, volume=0)], tempo=500003),
#  MIDIState(time=5685, notes=[MIDINote(note=69, volume=0), MIDINote(note=72, volume=0)], tempo=500003),
#  MIDIState(time=6134, notes=[MIDINote(note=57, volume=0), MIDINote(note=72, volume=0)], tempo=500003),
#  MIDIState(time=6165, notes=[MIDINote(note=72, volume=0), MIDINote(note=76, volume=0)], tempo=500003),
#  MIDIState(time=6195, notes=[MIDINote(note=72, volume=0), MIDINote(note=76, volume=0)], tempo=500003),
#  MIDIState(time=6675, notes=[MIDINote(note=72, volume=0), MIDINote(note=76, volume=0)], tempo=500003),
#  MIDIState(time=6705, notes=[MIDINote(note=72, volume=0), MIDINote(note=76, volume=0)], tempo=500003),
#  MIDIState(time=7179, notes=[MIDINote(note=57, volume=0), MIDINote(note=76, volume=0)], tempo=500003),
#  MIDIState(time=7180, notes=[MIDINote(note=71, volume=0), MIDINote(note=74, volume=0)], tempo=500003),
#  MIDIState(time=7210, notes=[MIDINote(note=71, volume=0), MIDINote(note=74, volume=0)], tempo=500003),
#  MIDIState(time=7654, notes=[MIDINote(note=45, volume=0), MIDINote(note=74, volume=0)], tempo=500003),
#  MIDIState(time=7685, notes=[MIDINote(note=69, volume=0), MIDINote(note=72, volume=0)], tempo=500003),
#  MIDIState(time=7715, notes=[MIDINote(note=69, volume=0), MIDINote(note=72, volume=0)], tempo=500003),
#  MIDIState(time=8161, notes=[MIDINote(note=57, volume=0), MIDINote(note=72, volume=0)], tempo=500003),
#  MIDIState(time=8191, notes=[MIDINote(note=57, volume=0), MIDINote(note=72, volume=0)], tempo=500003),
#  MIDIState(time=8196, notes=[MIDINote(note=68, volume=0), MIDINote(note=71, volume=0)], tempo=500003),
#  MIDIState(time=8222, notes=[MIDINote(note=68, volume=0), MIDINote(note=71, volume=0)], tempo=500003),
#  MIDIState(time=8707, notes=[MIDINote(note=44, volume=0), MIDINote(note=71, volume=0)], tempo=500003),
#  MIDIState(time=8738, notes=[MIDINote(note=64, volume=0), MIDINote(note=71, volume=0)], tempo=500003),
#  MIDIState(time=8768, notes=[MIDINote(note=64, volume=0), MIDINote(note=71, volume=0)], tempo=500003),
#  MIDIState(time=9215, notes=[MIDINote(note=56, volume=0), MIDINote(note=71, volume=0)], tempo=500003),
#  MIDIState(time=9246, notes=[MIDINote(note=68, volume=0), MIDINote(note=71, volume=0)], tempo=500003),
#  MIDIState(time=9276, notes=[MIDINote(note=68, volume=0), MIDINote(note=71, volume=0)], tempo=500003),
#  MIDIState(time=9720, notes=[MIDINote(note=44, volume=0), MIDINote(note=71, volume=0)], tempo=500003),
#  MIDIState(time=9751, notes=[MIDINote(note=69, volume=0), MIDINote(note=72, volume=0)], tempo=500003),
#  MIDIState(time=9781, notes=[MIDINote(note=69, volume=0), MIDINote(note=72, volume=0)], tempo=500003),
#  MIDIState(time=10230, notes=[MIDINote(note=56, volume=0), MIDINote(note=72, volume=0)], tempo=500003),
#  MIDIState(time=10261, notes=[MIDINote(note=71, volume=0), MIDINote(note=74, volume=0)], tempo=500003),
#  MIDIState(time=10291, notes=[MIDINote(note=71, volume=0), MIDINote(note=74, volume=0)], tempo=500003),
#  MIDIState(time=10496, notes=[MIDINote(note=71, volume=0), MIDINote(note=74, volume=0)], tempo=504434),
#  MIDIState(time=10752, notes=[MIDINote(note=71, volume=0), MIDINote(note=74, volume=0)], tempo=506432),
#  MIDIState(time=10771, notes=[MIDINote(note=71, volume=0), MIDINote(note=74, volume=0)], tempo=506432),
#  MIDIState(time=10801, notes=[MIDINote(note=71, volume=0), MIDINote(note=74, volume=0)], tempo=506432),
#  MIDIState(time=11008, notes=[MIDINote(note=71, volume=0), MIDINote(note=74, volume=0)], tempo=508697),
#  MIDIState(time=11264, notes=[MIDINote(note=71, volume=0), MIDINote(note=74, volume=0)], tempo=513029),
#  MIDIState(time=11275, notes=[MIDINote(note=52, volume=0), MIDINote(note=74, volume=0)], tempo=513029),
#  MIDIState(time=11276, notes=[MIDINote(note=72, volume=0), MIDINote(note=76, volume=0)], tempo=513029),
#  MIDIState(time=11306, notes=[MIDINote(note=72, volume=0), MIDINote(note=76, volume=0)], tempo=513029),
#  MIDIState(time=11520, notes=[MIDINote(note=72, volume=0), MIDINote(note=76, volume=0)], tempo=515093),
#  MIDIState(time=11776, notes=[MIDINote(note=72, volume=0), MIDINote(note=76, volume=0)], tempo=517436),
#  MIDIState(time=11781, notes=[MIDINote(note=72, volume=0), MIDINote(note=76, volume=0)], tempo=517436),
#  MIDIState(time=11811, notes=[MIDINote(note=72, volume=0), MIDINote(note=76, volume=0)], tempo=517436),
#  MIDIState(time=12032, notes=[MIDINote(note=72, volume=0), MIDINote(note=76, volume=0)], tempo=519535),
#  MIDIState(time=12287, notes=[MIDINote(note=52, volume=0), MIDINote(note=76, volume=0)], tempo=519535),
#  MIDIState(time=12292, notes=[MIDINote(note=69, volume=0), MIDINote(note=72, volume=0)], tempo=519535),
#  MIDIState(time=12318, notes=[MIDINote(note=69, volume=0), MIDINote(note=72, volume=0)], tempo=519535),
#  MIDIState(time=12544, notes=[MIDINote(note=69, volume=0), MIDINote(note=72, volume=0)], tempo=500003),
#  MIDIState(time=12834, notes=[MIDINote(note=69, volume=0), MIDINote(note=72, volume=0)], tempo=500003),
#  MIDIState(time=12864, notes=[MIDINote(note=69, volume=0), MIDINote(note=72, volume=0)], tempo=500003),
#  MIDIState(time=13342, notes=[MIDINote(note=64, volume=0), MIDINote(note=69, volume=0)], tempo=500003),
#  MIDIState(time=13372, notes=[MIDINote(note=64, volume=0), MIDINote(note=69, volume=0)], tempo=500003),
#  MIDIState(time=13847, notes=[MIDINote(note=64, volume=0), MIDINote(note=69, volume=0)], tempo=500003),
#  MIDIState(time=13877, notes=[MIDINote(note=64, volume=0), MIDINote(note=69, volume=0)], tempo=500003),
#  MIDIState(time=14357, notes=[MIDINote(note=64, volume=0), MIDINote(note=69, volume=0)], tempo=500003),
#  MIDIState(time=14387, notes=[MIDINote(note=64, volume=0), MIDINote(note=69, volume=0)], tempo=500003),
#  MIDIState(time=14867, notes=[MIDINote(note=64, volume=0), MIDINote(note=69, volume=0)], tempo=500003),
#  MIDIState(time=14897, notes=[MIDINote(note=64, volume=0), MIDINote(note=69, volume=0)], tempo=500003),
#  MIDIState(time=15372, notes=[MIDINote(note=64, volume=0), MIDINote(note=69, volume=0)], tempo=500003),
#  MIDIState(time=15402, notes=[MIDINote(note=64, volume=0), MIDINote(note=69, volume=0)], tempo=500003),
#  MIDIState(time=15877, notes=[MIDINote(note=64, volume=0), MIDINote(note=69, volume=0)], tempo=500003),
#  MIDIState(time=15907, notes=[MIDINote(note=64, volume=0), MIDINote(note=69, volume=0)], tempo=500003),
#  MIDIState(time=16383, notes=[MIDINote(note=48, volume=0), MIDINote(note=69, volume=0)], tempo=500003),
#  MIDIState(time=16388, notes=[MIDINote(note=48, volume=0), MIDINote(note=50, volume=0)], tempo=500003),
#  MIDIState(time=16414, notes=[MIDINote(note=50, volume=0), MIDINote(note=50, volume=0)], tempo=500003),
#  MIDIState(time=16930, notes=[MIDINote(note=65, volume=0), MIDINote(note=74, volume=0)], tempo=500003),
#  MIDIState(time=16960, notes=[MIDINote(note=65, volume=0), MIDINote(note=74, volume=0)], tempo=500003),
#  MIDIState(time=17468, notes=[MIDINote(note=65, volume=0), MIDINote(note=74, volume=0)], tempo=500003),
#  MIDIState(time=17943, notes=[MIDINote(note=69, volume=0), MIDINote(note=77, volume=0)], tempo=500003),
#  MIDIState(time=18422, notes=[MIDINote(note=38, volume=0), MIDINote(note=77, volume=0)], tempo=500003),
#  MIDIState(time=18453, notes=[MIDINote(note=72, volume=0), MIDINote(note=81, volume=0)], tempo=500003),
#  MIDIState(time=18483, notes=[MIDINote(note=72, volume=0), MIDINote(note=81, volume=0)], tempo=500003),
#  MIDIState(time=18688, notes=[MIDINote(note=72, volume=0), MIDINote(note=81, volume=0)], tempo=502210),
#  MIDIState(time=18944, notes=[MIDINote(note=72, volume=0), MIDINote(note=81, volume=0)], tempo=504434),
#  MIDIState(time=18963, notes=[MIDINote(note=72, volume=0), MIDINote(note=81, volume=0)], tempo=504434),
#  MIDIState(time=19211, notes=[MIDINote(note=72, volume=0), MIDINote(note=81, volume=0)], tempo=504434),
#  MIDIState(time=19456, notes=[MIDINote(note=72, volume=0), MIDINote(note=81, volume=0)], tempo=506432),
#  MIDIState(time=19467, notes=[MIDINote(note=38, volume=0), MIDINote(note=72, volume=0)], tempo=506432),
#  MIDIState(time=19468, notes=[MIDINote(note=72, volume=0), MIDINote(note=79, volume=0)], tempo=506432),
#  MIDIState(time=19482, notes=[MIDINote(note=71, volume=0), MIDINote(note=79, volume=0)], tempo=506432),
#  MIDIState(time=19498, notes=[MIDINote(note=71, volume=0), MIDINote(note=79, volume=0)], tempo=506432),
#  MIDIState(time=19942, notes=[MIDINote(note=45, volume=0), MIDINote(note=79, volume=0)], tempo=506432),
#  MIDIState(time=19968, notes=[MIDINote(note=45, volume=0), MIDINote(note=79, volume=0)], tempo=508697),
#  MIDIState(time=19973, notes=[MIDINote(note=69, volume=0), MIDINote(note=77, volume=0)], tempo=508697),
#  MIDIState(time=20003, notes=[MIDINote(note=69, volume=0), MIDINote(note=77, volume=0)], tempo=508697),
#  MIDIState(time=20224, notes=[MIDINote(note=69, volume=0), MIDINote(note=77, volume=0)], tempo=510726),
#  MIDIState(time=20449, notes=[MIDINote(note=41, volume=0), MIDINote(note=77, volume=0)], tempo=510726),
#  MIDIState(time=20479, notes=[MIDINote(note=41, volume=0), MIDINote(note=77, volume=0)], tempo=510726),
#  MIDIState(time=20480, notes=[MIDINote(note=41, volume=0), MIDINote(note=77, volume=0)], tempo=500003),
#  MIDIState(time=20484, notes=[MIDINote(note=67, volume=0), MIDINote(note=76, volume=0)], tempo=500003),
#  MIDIState(time=20510, notes=[MIDINote(note=67, volume=0), MIDINote(note=76, volume=0)], tempo=500003),
#  MIDIState(time=21026, notes=[MIDINote(note=67, volume=0), MIDINote(note=76, volume=0)], tempo=500003),
#  MIDIState(time=21056, notes=[MIDINote(note=67, volume=0), MIDINote(note=76, volume=0)], tempo=500003),
#  MIDIState(time=21564, notes=[MIDINote(note=67, volume=0), MIDINote(note=76, volume=0)], tempo=500003),
#  MIDIState(time=22039, notes=[MIDINote(note=64, volume=0), MIDINote(note=72, volume=0)], tempo=500003),
#  MIDIState(time=22518, notes=[MIDINote(note=48, volume=0), MIDINote(note=72, volume=0)], tempo=500003),
#  MIDIState(time=22549, notes=[MIDINote(note=67, volume=0), MIDINote(note=76, volume=0)], tempo=500003),
#  MIDIState(time=22579, notes=[MIDINote(note=67, volume=0), MIDINote(note=76, volume=0)], tempo=500003),
#  MIDIState(time=23028, notes=[MIDINote(note=36, volume=0), MIDINote(note=76, volume=0)], tempo=500003),
#  MIDIState(time=23059, notes=[MIDINote(note=69, volume=0), MIDINote(note=76, volume=0)], tempo=500003),
#  MIDIState(time=23089, notes=[MIDINote(note=69, volume=0), MIDINote(note=76, volume=0)], tempo=500003),
#  MIDIState(time=23291, notes=[MIDINote(note=43, volume=0), MIDINote(note=76, volume=0)], tempo=500003),
#  MIDIState(time=23307, notes=[MIDINote(note=67, volume=0), MIDINote(note=76, volume=0)], tempo=500003),
#  MIDIState(time=23548, notes=[MIDINote(note=43, volume=0), MIDINote(note=76, volume=0)], tempo=500003),
#  MIDIState(time=23563, notes=[MIDINote(note=43, volume=0), MIDINote(note=76, volume=0)], tempo=500003),
#  MIDIState(time=23564, notes=[MIDINote(note=65, volume=0), MIDINote(note=74, volume=0)], tempo=500003),
#  MIDIState(time=23594, notes=[MIDINote(note=65, volume=0), MIDINote(note=74, volume=0)], tempo=500003),
#  MIDIState(time=24038, notes=[MIDINote(note=74, volume=0), MIDINote(note=74, volume=0)], tempo=500003),
#  MIDIState(time=24069, notes=[MIDINote(note=64, volume=0), MIDINote(note=72, volume=0)], tempo=500003),
#  MIDIState(time=24545, notes=[MIDINote(note=43, volume=0), MIDINote(note=72, volume=0)], tempo=500003),
#  MIDIState(time=24575, notes=[MIDINote(note=43, volume=0), MIDINote(note=72, volume=0)], tempo=500003),
#  MIDIState(time=24580, notes=[MIDINote(note=68, volume=0), MIDINote(note=71, volume=0)], tempo=500003),
#  MIDIState(time=24606, notes=[MIDINote(note=68, volume=0), MIDINote(note=71, volume=0)], tempo=500003),
#  MIDIState(time=25091, notes=[MIDINote(note=47, volume=0), MIDINote(note=71, volume=0)], tempo=500003),
#  MIDIState(time=25122, notes=[MIDINote(note=64, volume=0), MIDINote(note=71, volume=0)], tempo=500003),
#  MIDIState(time=25152, notes=[MIDINote(note=64, volume=0), MIDINote(note=71, volume=0)], tempo=500003),
#  MIDIState(time=25599, notes=[MIDINote(note=59, volume=0), MIDINote(note=71, volume=0)], tempo=500003),
#  MIDIState(time=25630, notes=[MIDINote(note=68, volume=0), MIDINote(note=71, volume=0)], tempo=500003),
#  MIDIState(time=25660, notes=[MIDINote(note=68, volume=0), MIDINote(note=71, volume=0)], tempo=500003),
#  MIDIState(time=26104, notes=[MIDINote(note=71, volume=0), MIDINote(note=71, volume=0)], tempo=500003),
#  MIDIState(time=26135, notes=[MIDINote(note=69, volume=0), MIDINote(note=72, volume=0)], tempo=500003),
#  MIDIState(time=26614, notes=[MIDINote(note=59, volume=0), MIDINote(note=72, volume=0)], tempo=500003),
#  MIDIState(time=26645, notes=[MIDINote(note=71, volume=0), MIDINote(note=74, volume=0)], tempo=500003),
#  MIDIState(time=26675, notes=[MIDINote(note=71, volume=0), MIDINote(note=74, volume=0)], tempo=500003),
#  MIDIState(time=27124, notes=[MIDINote(note=74, volume=0), MIDINote(note=74, volume=0)], tempo=500003),
#  MIDIState(time=27155, notes=[MIDINote(note=68, volume=0), MIDINote(note=74, volume=0)], tempo=500003),
#  MIDIState(time=27629, notes=[MIDINote(note=52, volume=0), MIDINote(note=74, volume=0)], tempo=500003),
#  MIDIState(time=27659, notes=[MIDINote(note=52, volume=0), MIDINote(note=74, volume=0)], tempo=500003),
#  MIDIState(time=27660, notes=[MIDINote(note=72, volume=0), MIDINote(note=76, volume=0)], tempo=500003),
#  MIDIState(time=27690, notes=[MIDINote(note=72, volume=0), MIDINote(note=76, volume=0)], tempo=500003),
#  MIDIState(time=28134, notes=[MIDINote(note=76, volume=0), MIDINote(note=76, volume=0)], tempo=500003),
#  MIDIState(time=28165, notes=[MIDINote(note=68, volume=0), MIDINote(note=76, volume=0)], tempo=500003),
#  MIDIState(time=28641, notes=[MIDINote(note=56, volume=0), MIDINote(note=76, volume=0)], tempo=500003),
#  MIDIState(time=28671, notes=[MIDINote(note=56, volume=0), MIDINote(note=76, volume=0)], tempo=500003),
#  MIDIState(time=28676, notes=[MIDINote(note=69, volume=0), MIDINote(note=72, volume=0)], tempo=500003),
#  MIDIState(time=28702, notes=[MIDINote(note=69, volume=0), MIDINote(note=72, volume=0)], tempo=500003),
#  MIDIState(time=29187, notes=[MIDINote(note=45, volume=0), MIDINote(note=72, volume=0)], tempo=500003),
#  MIDIState(time=29218, notes=[MIDINote(note=64, volume=0), MIDINote(note=72, volume=0)], tempo=500003),
#  MIDIState(time=29248, notes=[MIDINote(note=64, volume=0), MIDINote(note=72, volume=0)], tempo=500003),
#  MIDIState(time=29695, notes=[MIDINote(note=52, volume=0), MIDINote(note=72, volume=0)], tempo=500003),
#  MIDIState(time=29726, notes=[MIDINote(note=64, volume=0), MIDINote(note=69, volume=0)], tempo=500003),
#  MIDIState(time=29756, notes=[MIDINote(note=64, volume=0), MIDINote(note=69, volume=0)], tempo=500003),
#  MIDIState(time=30231, notes=[MIDINote(note=64, volume=0), MIDINote(note=69, volume=0)], tempo=500003),
#  MIDIState(time=30261, notes=[MIDINote(note=64, volume=0), MIDINote(note=69, volume=0)], tempo=500003),
#  MIDIState(time=30741, notes=[MIDINote(note=64, volume=0), MIDINote(note=69, volume=0)], tempo=500003),
#  MIDIState(time=30771, notes=[MIDINote(note=64, volume=0), MIDINote(note=69, volume=0)], tempo=500003),
#  MIDIState(time=31755, notes=[MIDINote(note=64, volume=0), MIDINote(note=69, volume=0)], tempo=500003),
#  MIDIState(time=32772, notes=[MIDINote(note=60, volume=0), MIDINote(note=64, volume=0)], tempo=500003),
#  MIDIState(time=33314, notes=[MIDINote(note=60, volume=0), MIDINote(note=64, volume=0)], tempo=500003),
#  MIDIState(time=33344, notes=[MIDINote(note=60, volume=0), MIDINote(note=64, volume=0)], tempo=500003),
#  MIDIState(time=33822, notes=[MIDINote(note=60, volume=0), MIDINote(note=64, volume=0)], tempo=500003),
#  MIDIState(time=33852, notes=[MIDINote(note=60, volume=0), MIDINote(note=64, volume=0)], tempo=500003),
#  MIDIState(time=34327, notes=[MIDINote(note=60, volume=0), MIDINote(note=64, volume=0)], tempo=500003),
#  MIDIState(time=34357, notes=[MIDINote(note=60, volume=0), MIDINote(note=64, volume=0)], tempo=500003),
#  MIDIState(time=34837, notes=[MIDINote(note=57, volume=0), MIDINote(note=60, volume=0)], tempo=500003),
#  MIDIState(time=34867, notes=[MIDINote(note=57, volume=0), MIDINote(note=60, volume=0)], tempo=500003),
#  MIDIState(time=35347, notes=[MIDINote(note=57, volume=0), MIDINote(note=60, volume=0)], tempo=500003),
#  MIDIState(time=35377, notes=[MIDINote(note=57, volume=0), MIDINote(note=60, volume=0)], tempo=500003),
#  MIDIState(time=35852, notes=[MIDINote(note=57, volume=0), MIDINote(note=60, volume=0)], tempo=500003),
#  MIDIState(time=35882, notes=[MIDINote(note=57, volume=0), MIDINote(note=60, volume=0)], tempo=500003),
#  MIDIState(time=36357, notes=[MIDINote(note=57, volume=0), MIDINote(note=60, volume=0)], tempo=500003),
#  MIDIState(time=36387, notes=[MIDINote(note=57, volume=0), MIDINote(note=60, volume=0)], tempo=500003),
#  MIDIState(time=36863, notes=[MIDINote(note=52, volume=0), MIDINote(note=60, volume=0)], tempo=500003),
#  MIDIState(time=36868, notes=[MIDINote(note=59, volume=0), MIDINote(note=62, volume=0)], tempo=500003),
#  MIDIState(time=36894, notes=[MIDINote(note=59, volume=0), MIDINote(note=62, volume=0)], tempo=500003),
#  MIDIState(time=37410, notes=[MIDINote(note=59, volume=0), MIDINote(note=62, volume=0)], tempo=500003),
#  MIDIState(time=37440, notes=[MIDINote(note=59, volume=0), MIDINote(note=62, volume=0)], tempo=500003),
#  MIDIState(time=37918, notes=[MIDINote(note=59, volume=0), MIDINote(note=62, volume=0)], tempo=500003),
#  MIDIState(time=37948, notes=[MIDINote(note=59, volume=0), MIDINote(note=62, volume=0)], tempo=500003),
#  MIDIState(time=38423, notes=[MIDINote(note=59, volume=0), MIDINote(note=62, volume=0)], tempo=500003),
#  MIDIState(time=38453, notes=[MIDINote(note=59, volume=0), MIDINote(note=62, volume=0)], tempo=500003),
#  MIDIState(time=38933, notes=[MIDINote(note=56, volume=0), MIDINote(note=59, volume=0)], tempo=500003),
#  MIDIState(time=38963, notes=[MIDINote(note=56, volume=0), MIDINote(note=59, volume=0)], tempo=500003),
#  MIDIState(time=39168, notes=[MIDINote(note=56, volume=0), MIDINote(note=59, volume=0)], tempo=504434),
#  MIDIState(time=39424, notes=[MIDINote(note=56, volume=0), MIDINote(note=59, volume=0)], tempo=506432),
#  MIDIState(time=39443, notes=[MIDINote(note=56, volume=0), MIDINote(note=59, volume=0)], tempo=506432),
#  MIDIState(time=39473, notes=[MIDINote(note=56, volume=0), MIDINote(note=59, volume=0)], tempo=506432),
#  MIDIState(time=39680, notes=[MIDINote(note=56, volume=0), MIDINote(note=59, volume=0)], tempo=508697),
#  MIDIState(time=39936, notes=[MIDINote(note=56, volume=0), MIDINote(note=59, volume=0)], tempo=513029),
#  MIDIState(time=39948, notes=[MIDINote(note=56, volume=0), MIDINote(note=59, volume=0)], tempo=513029),
#  MIDIState(time=39978, notes=[MIDINote(note=56, volume=0), MIDINote(note=59, volume=0)], tempo=513029),
#  MIDIState(time=40192, notes=[MIDINote(note=56, volume=0), MIDINote(note=59, volume=0)], tempo=515093),
#  MIDIState(time=40448, notes=[MIDINote(note=56, volume=0), MIDINote(note=59, volume=0)], tempo=517436),
#  MIDIState(time=40453, notes=[MIDINote(note=56, volume=0), MIDINote(note=59, volume=0)], tempo=517436),
#  MIDIState(time=40483, notes=[MIDINote(note=56, volume=0), MIDINote(note=59, volume=0)], tempo=517436),
#  MIDIState(time=40704, notes=[MIDINote(note=56, volume=0), MIDINote(note=59, volume=0)], tempo=519535),
#  MIDIState(time=40959, notes=[MIDINote(note=52, volume=0), MIDINote(note=59, volume=0)], tempo=519535),
#  MIDIState(time=40964, notes=[MIDINote(note=57, volume=0), MIDINote(note=60, volume=0)], tempo=519535),
#  MIDIState(time=40990, notes=[MIDINote(note=57, volume=0), MIDINote(note=60, volume=0)], tempo=519535),
#  MIDIState(time=41216, notes=[MIDINote(note=57, volume=0), MIDINote(note=60, volume=0)], tempo=500003),
#  MIDIState(time=41506, notes=[MIDINote(note=57, volume=0), MIDINote(note=60, volume=0)], tempo=500003),
#  MIDIState(time=41536, notes=[MIDINote(note=57, volume=0), MIDINote(note=60, volume=0)], tempo=500003),
#  MIDIState(time=42014, notes=[MIDINote(note=57, volume=0), MIDINote(note=60, volume=0)], tempo=500003),
#  MIDIState(time=42044, notes=[MIDINote(note=57, volume=0), MIDINote(note=60, volume=0)], tempo=500003),
#  MIDIState(time=42519, notes=[MIDINote(note=57, volume=0), MIDINote(note=60, volume=0)], tempo=500003),
#  MIDIState(time=42549, notes=[MIDINote(note=57, volume=0), MIDINote(note=60, volume=0)], tempo=500003),
#  MIDIState(time=43029, notes=[MIDINote(note=52, volume=0), MIDINote(note=57, volume=0)], tempo=500003),
#  MIDIState(time=43059, notes=[MIDINote(note=45, volume=0), MIDINote(note=57, volume=0)], tempo=500003),
#  MIDIState(time=43539, notes=[MIDINote(note=52, volume=0), MIDINote(note=57, volume=0)], tempo=500003),
#  MIDIState(time=43569, notes=[MIDINote(note=52, volume=0), MIDINote(note=57, volume=0)], tempo=500003),
#  MIDIState(time=44044, notes=[MIDINote(note=52, volume=0), MIDINote(note=57, volume=0)], tempo=500003),
#  MIDIState(time=44074, notes=[MIDINote(note=45, volume=0), MIDINote(note=57, volume=0)], tempo=500003),
#  MIDIState(time=44549, notes=[MIDINote(note=52, volume=0), MIDINote(note=57, volume=0)], tempo=500003),
#  MIDIState(time=44579, notes=[MIDINote(note=52, volume=0), MIDINote(note=57, volume=0)], tempo=500003),
#  MIDIState(time=45055, notes=[MIDINote(note=52, volume=0), MIDINote(note=57, volume=0)], tempo=500003),
#  MIDIState(time=45060, notes=[MIDINote(note=52, volume=0), MIDINote(note=56, volume=0)], tempo=500003),
#  MIDIState(time=45086, notes=[MIDINote(note=44, volume=0), MIDINote(note=56, volume=0)], tempo=500003),
#  MIDIState(time=45602, notes=[MIDINote(note=52, volume=0), MIDINote(note=56, volume=0)], tempo=500003),
#  MIDIState(time=45632, notes=[MIDINote(note=52, volume=0), MIDINote(note=56, volume=0)], tempo=500003),
#  MIDIState(time=46110, notes=[MIDINote(note=52, volume=0), MIDINote(note=56, volume=0)], tempo=500003),
#  MIDIState(time=46140, notes=[MIDINote(note=44, volume=0), MIDINote(note=56, volume=0)], tempo=500003),
#  MIDIState(time=46615, notes=[MIDINote(note=52, volume=0), MIDINote(note=56, volume=0)], tempo=500003),
#  MIDIState(time=46645, notes=[MIDINote(note=52, volume=0), MIDINote(note=56, volume=0)], tempo=500003),
#  MIDIState(time=47125, notes=[MIDINote(note=56, volume=0), MIDINote(note=59, volume=0)], tempo=500003),
#  MIDIState(time=47360, notes=[MIDINote(note=56, volume=0), MIDINote(note=59, volume=0)], tempo=504434),
#  MIDIState(time=47616, notes=[MIDINote(note=56, volume=0), MIDINote(note=59, volume=0)], tempo=506432),
#  MIDIState(time=47635, notes=[MIDINote(note=56, volume=0), MIDINote(note=59, volume=0)], tempo=506432),
#  MIDIState(time=47665, notes=[MIDINote(note=56, volume=0), MIDINote(note=59, volume=0)], tempo=506432),
#  MIDIState(time=47872, notes=[MIDINote(note=56, volume=0), MIDINote(note=59, volume=0)], tempo=508697),
#  MIDIState(time=48128, notes=[MIDINote(note=56, volume=0), MIDINote(note=59, volume=0)], tempo=513029),
#  MIDIState(time=48140, notes=[MIDINote(note=56, volume=0), MIDINote(note=59, volume=0)], tempo=513029),
#  MIDIState(time=48170, notes=[MIDINote(note=56, volume=0), MIDINote(note=59, volume=0)], tempo=513029),
#  MIDIState(time=48384, notes=[MIDINote(note=56, volume=0), MIDINote(note=59, volume=0)], tempo=515093),
#  MIDIState(time=48640, notes=[MIDINote(note=56, volume=0), MIDINote(note=59, volume=0)], tempo=517436),
#  MIDIState(time=48645, notes=[MIDINote(note=56, volume=0), MIDINote(note=59, volume=0)], tempo=517436),
#  MIDIState(time=48675, notes=[MIDINote(note=56, volume=0), MIDINote(note=59, volume=0)], tempo=517436),
#  MIDIState(time=48896, notes=[MIDINote(note=56, volume=0), MIDINote(note=59, volume=0)], tempo=519535),
#  MIDIState(time=49151, notes=[MIDINote(note=52, volume=0), MIDINote(note=59, volume=0)], tempo=519535),
#  MIDIState(time=49156, notes=[MIDINote(note=60, volume=0), MIDINote(note=64, volume=0)], tempo=519535),
#  MIDIState(time=49182, notes=[MIDINote(note=60, volume=0), MIDINote(note=64, volume=0)], tempo=519535),
#  MIDIState(time=49408, notes=[MIDINote(note=60, volume=0), MIDINote(note=64, volume=0)], tempo=500003),
#  MIDIState(time=49698, notes=[MIDINote(note=60, volume=0), MIDINote(note=64, volume=0)], tempo=500003),
#  MIDIState(time=49728, notes=[MIDINote(note=60, volume=0), MIDINote(note=64, volume=0)], tempo=500003),
#  MIDIState(time=50206, notes=[MIDINote(note=60, volume=0), MIDINote(note=64, volume=0)], tempo=500003),
#  MIDIState(time=50236, notes=[MIDINote(note=60, volume=0), MIDINote(note=64, volume=0)], tempo=500003),
#  MIDIState(time=50711, notes=[MIDINote(note=60, volume=0), MIDINote(note=64, volume=0)], tempo=500003),
#  MIDIState(time=50741, notes=[MIDINote(note=60, volume=0), MIDINote(note=64, volume=0)], tempo=500003),
#  MIDIState(time=51221, notes=[MIDINote(note=57, volume=0), MIDINote(note=60, volume=0)], tempo=500003),
#  MIDIState(time=51251, notes=[MIDINote(note=57, volume=0), MIDINote(note=60, volume=0)], tempo=500003),
#  MIDIState(time=51731, notes=[MIDINote(note=57, volume=0), MIDINote(note=60, volume=0)], tempo=500003),
#  MIDIState(time=51761, notes=[MIDINote(note=57, volume=0), MIDINote(note=60, volume=0)], tempo=500003),
#  MIDIState(time=52236, notes=[MIDINote(note=57, volume=0), MIDINote(note=60, volume=0)], tempo=500003),
#  MIDIState(time=52266, notes=[MIDINote(note=57, volume=0), MIDINote(note=60, volume=0)], tempo=500003),
#  MIDIState(time=52741, notes=[MIDINote(note=57, volume=0), MIDINote(note=60, volume=0)], tempo=500003),
#  MIDIState(time=52771, notes=[MIDINote(note=57, volume=0), MIDINote(note=60, volume=0)], tempo=500003),
#  MIDIState(time=53247, notes=[MIDINote(note=52, volume=0), MIDINote(note=60, volume=0)], tempo=500003),
#  MIDIState(time=53252, notes=[MIDINote(note=59, volume=0), MIDINote(note=62, volume=0)], tempo=500003),
#  MIDIState(time=53278, notes=[MIDINote(note=59, volume=0), MIDINote(note=62, volume=0)], tempo=500003),
#  MIDIState(time=53794, notes=[MIDINote(note=59, volume=0), MIDINote(note=62, volume=0)], tempo=500003),
#  MIDIState(time=53824, notes=[MIDINote(note=59, volume=0), MIDINote(note=62, volume=0)], tempo=500003),
#  MIDIState(time=54302, notes=[MIDINote(note=59, volume=0), MIDINote(note=62, volume=0)], tempo=500003),
#  MIDIState(time=54332, notes=[MIDINote(note=59, volume=0), MIDINote(note=62, volume=0)], tempo=500003),
#  MIDIState(time=54807, notes=[MIDINote(note=59, volume=0), MIDINote(note=62, volume=0)], tempo=500003),
#  MIDIState(time=54837, notes=[MIDINote(note=59, volume=0), MIDINote(note=62, volume=0)], tempo=500003),
#  MIDIState(time=55317, notes=[MIDINote(note=56, volume=0), MIDINote(note=59, volume=0)], tempo=500003),
#  MIDIState(time=55347, notes=[MIDINote(note=56, volume=0), MIDINote(note=59, volume=0)], tempo=500003),
#  MIDIState(time=55827, notes=[MIDINote(note=56, volume=0), MIDINote(note=59, volume=0)], tempo=500003),
#  MIDIState(time=55857, notes=[MIDINote(note=56, volume=0), MIDINote(note=59, volume=0)], tempo=500003),
#  MIDIState(time=56332, notes=[MIDINote(note=56, volume=0), MIDINote(note=59, volume=0)], tempo=500003),
#  MIDIState(time=56362, notes=[MIDINote(note=56, volume=0), MIDINote(note=59, volume=0)], tempo=500003),
#  MIDIState(time=56837, notes=[MIDINote(note=56, volume=0), MIDINote(note=59, volume=0)], tempo=500003),
#  MIDIState(time=56867, notes=[MIDINote(note=56, volume=0), MIDINote(note=59, volume=0)], tempo=500003),
#  MIDIState(time=57343, notes=[MIDINote(note=52, volume=0), MIDINote(note=59, volume=0)], tempo=500003),
#  MIDIState(time=57348, notes=[MIDINote(note=57, volume=0), MIDINote(note=60, volume=0)], tempo=500003),
#  MIDIState(time=57374, notes=[MIDINote(note=57, volume=0), MIDINote(note=60, volume=0)], tempo=500003),
#  MIDIState(time=57890, notes=[MIDINote(note=57, volume=0), MIDINote(note=60, volume=0)], tempo=500003),
#  MIDIState(time=57920, notes=[MIDINote(note=57, volume=0), MIDINote(note=60, volume=0)], tempo=500003),
#  MIDIState(time=58398, notes=[MIDINote(note=60, volume=0), MIDINote(note=64, volume=0)], tempo=500003),
#  MIDIState(time=58428, notes=[MIDINote(note=60, volume=0), MIDINote(note=64, volume=0)], tempo=500003),
#  MIDIState(time=58903, notes=[MIDINote(note=60, volume=0), MIDINote(note=64, volume=0)], tempo=500003),
#  MIDIState(time=58933, notes=[MIDINote(note=60, volume=0), MIDINote(note=64, volume=0)], tempo=500003),
#  MIDIState(time=59413, notes=[MIDINote(note=64, volume=0), MIDINote(note=69, volume=0)], tempo=500003),
#  MIDIState(time=59443, notes=[MIDINote(note=64, volume=0), MIDINote(note=69, volume=0)], tempo=500003),
#  MIDIState(time=59923, notes=[MIDINote(note=64, volume=0), MIDINote(note=69, volume=0)], tempo=500003),
#  MIDIState(time=59953, notes=[MIDINote(note=64, volume=0), MIDINote(note=69, volume=0)], tempo=500003),
#  MIDIState(time=60428, notes=[MIDINote(note=64, volume=0), MIDINote(note=69, volume=0)], tempo=500003),
#  MIDIState(time=60458, notes=[MIDINote(note=64, volume=0), MIDINote(note=69, volume=0)], tempo=500003),
#  MIDIState(time=60933, notes=[MIDINote(note=64, volume=0), MIDINote(note=69, volume=0)], tempo=500003),
#  MIDIState(time=60963, notes=[MIDINote(note=64, volume=0), MIDINote(note=69, volume=0)], tempo=500003),
#  MIDIState(time=61439, notes=[MIDINote(note=52, volume=0), MIDINote(note=69, volume=0)], tempo=500003),
#  MIDIState(time=61444, notes=[MIDINote(note=64, volume=0), MIDINote(note=68, volume=0)], tempo=500003),
#  MIDIState(time=61470, notes=[MIDINote(note=64, volume=0), MIDINote(note=68, volume=0)], tempo=500003),
#  MIDIState(time=61986, notes=[MIDINote(note=64, volume=0), MIDINote(note=68, volume=0)], tempo=500003),
#  MIDIState(time=62016, notes=[MIDINote(note=64, volume=0), MIDINote(note=68, volume=0)], tempo=500003),
#  MIDIState(time=62494, notes=[MIDINote(note=64, volume=0), MIDINote(note=68, volume=0)], tempo=500003),
#  MIDIState(time=62524, notes=[MIDINote(note=64, volume=0), MIDINote(note=68, volume=0)], tempo=500003),
#  MIDIState(time=62999, notes=[MIDINote(note=64, volume=0), MIDINote(note=68, volume=0)], tempo=500003),
#  MIDIState(time=63029, notes=[MIDINote(note=64, volume=0), MIDINote(note=68, volume=0)], tempo=500003),
#  MIDIState(time=63509, notes=[MIDINote(note=64, volume=0), MIDINote(note=68, volume=0)], tempo=500003),
#  MIDIState(time=63539, notes=[MIDINote(note=64, volume=0), MIDINote(note=68, volume=0)], tempo=500003),
#  MIDIState(time=64019, notes=[MIDINote(note=64, volume=0), MIDINote(note=68, volume=0)], tempo=500003),
#  MIDIState(time=64049, notes=[MIDINote(note=64, volume=0), MIDINote(note=68, volume=0)], tempo=500003),
#  MIDIState(time=64524, notes=[MIDINote(note=64, volume=0), MIDINote(note=68, volume=0)], tempo=500003),
#  MIDIState(time=64554, notes=[MIDINote(note=64, volume=0), MIDINote(note=68, volume=0)], tempo=500003),
#  MIDIState(time=65029, notes=[MIDINote(note=64, volume=0), MIDINote(note=68, volume=0)], tempo=500003),
#  MIDIState(time=65059, notes=[MIDINote(note=64, volume=0), MIDINote(note=68, volume=0)], tempo=500003),
#  MIDIState(time=65535, notes=[MIDINote(note=52, volume=0), MIDINote(note=68, volume=0)], tempo=500003),
#  MIDIState(time=65566, notes=[MIDINote(note=52, volume=0), MIDINote(note=68, volume=0)], tempo=500003)]

# %%
def byte_enc(byte):
    return '{0:#04x}'.format(byte)

def hex_encode(value, bytes):
    def grab():
        nonlocal value
        byte = value & 0xff
        value = value >> 8
        return byte_enc(byte)
    bytestr = [grab() for b in range(bytes)]
    #bytestr.reverse()
    return bytestr

def make_ts(tone = [None, None], volume = [None, None],
            end_program = False, timer1_equals_timer2 = False, new_tempo = None,
            num_led_inst = 0, beat_number = 0):
    def opcode(idx):
        return (1 if tone[idx] is not None else 0) + (2 if volume[idx] is not None else 0)
    ts = hex_encode((beat_number & 0xffff) \
                + ((num_led_inst & 0x1f) << 16) \
                + (1 << 21 if new_tempo else 0) \
                + (1 << 22 if timer1_equals_timer2 else 0) \
                + (1 << 23 if end_program else 0) \
                + (opcode(1) << 24) \
                + (opcode(0) << 28), 4)
    if end_program: return ts
    if tone[0] is not None: ts.append(byte_enc(tone[0]))
    if volume[0] is not None: ts.append(byte_enc(volume[0]))
    if not timer1_equals_timer2:
        if tone[1] is not None: ts.append(byte_enc(tone[1]))
        if volume[1] is not None: ts.append(byte_enc(volume[1]))
    if new_tempo:
        ts += hex_encode(new_tempo, 4)
    return ts

# %%
make_ts(tone=[132,None])
# Out:
# ['0x00', '0x00', '0x00', '0x10', '0x84']

# %%
MAX_MIDI_BAR = 64
MAX_MIDI_TIME = MAX_MIDI_BAR * 4 * MIDI_TICKS_PER_BEAT
buffer = []
for i, s in enumerate(state_array_condensed):
    if s.time >= MAX_MIDI_TIME:
        break
    beat_num = int(s.time / MIDI_TICKS_PER_OUTPUT_TICK)
    if i == 0:
        prev_s = MIDIState(0, [], 0)
    else:
        prev_s = state_array_condensed[i - 1]
    tone = []
    volume = []
    msg = []
    req_ts = False
    for timer_id in range(2):
        if len(s.notes) > timer_id:
            if len(prev_s.notes) <= timer_id or prev_s.notes[timer_id].note != s.notes[timer_id].note:
                tone.append(s.notes[timer_id].note)
                msg.append('T%d NOTE->%d' % (timer_id + 1, s.notes[timer_id].note))
                req_ts = True
            else:
                tone.append(None)
            if len(prev_s.notes) <= timer_id or prev_s.notes[timer_id].volume != s.notes[timer_id].volume:
                volume.append(s.notes[timer_id].volume)                
                msg.append('T%d VOL->%d' % (timer_id + 1, s.notes[timer_id].volume))
                req_ts = True
            else:
                volume.append(None)
        else:
            msg.append('T%d OFF' % (timer_id + 1))
            req_ts = True
            tone.append(None)
            if prev_s.volume > 0: volume.append(0)
    new_tempo = s.tempo if s.tempo != prev_s.tempo else None
    if new_tempo:
        msg.append('TEMPO->%d' % new_tempo)
        req_ts = True
    if req_ts:
        ts = make_ts(tone=tone, volume=volume, beat_number=beat_num, new_tempo=new_tempo)
        buffer += ts
        print('%8d - %s\n\t\t%s' % (beat_num, ts, ', '.join(msg)))
buffer += make_ts(end_program=True)
print(len(buffer))
# Out:
#        0 - ['0x00', '0x00', '0x20', '0x33', '0x00', '0x00', '0x00', '0x00', '0x23', '0xa1', '0x07', '0x00']
# 		T1 NOTE->0, T1 VOL->0, T2 NOTE->0, T2 VOL->0, TEMPO->500003
#        2 - ['0x02', '0x00', '0x00', '0x11', '0x47', '0x4c']
# 		T1 NOTE->71, T2 NOTE->76
#      263 - ['0x07', '0x01', '0x00', '0x11', '0x44', '0x47']
# 		T1 NOTE->68, T2 NOTE->71
#      382 - ['0x7e', '0x01', '0x00', '0x10', '0x28']
# 		T1 NOTE->40
#      389 - ['0x85', '0x01', '0x00', '0x11', '0x45', '0x48']
# 		T1 NOTE->69, T2 NOTE->72
#      509 - ['0xfd', '0x01', '0x00', '0x10', '0x34']
# 		T1 NOTE->52
#      517 - ['0x05', '0x02', '0x00', '0x11', '0x47', '0x4a']
# 		T1 NOTE->71, T2 NOTE->74
#      576 - ['0x40', '0x02', '0x20', '0x00', '0x72', '0xb2', '0x07', '0x00']
# 		TEMPO->504434
#      637 - ['0x7d', '0x02', '0x00', '0x10', '0x28']
# 		T1 NOTE->40
#      640 - ['0x80', '0x02', '0x20', '0x00', '0x40', '0xba', '0x07', '0x00']
# 		TEMPO->506432
#      644 - ['0x84', '0x02', '0x00', '0x11', '0x34', '0x4c']
# 		T1 NOTE->52, T2 NOTE->76
#      704 - ['0xc0', '0x02', '0x20', '0x00', '0x19', '0xc3', '0x07', '0x00']
# 		TEMPO->508697
#      706 - ['0xc2', '0x02', '0x00', '0x01', '0x4a']
# 		T2 NOTE->74
#      768 - ['0x00', '0x03', '0x20', '0x00', '0x05', '0xd4', '0x07', '0x00']
# 		TEMPO->513029
#      771 - ['0x03', '0x03', '0x00', '0x11', '0x45', '0x48']
# 		T1 NOTE->69, T2 NOTE->72
#      832 - ['0x40', '0x03', '0x20', '0x00', '0x15', '0xdc', '0x07', '0x00']
# 		TEMPO->515093
#      889 - ['0x79', '0x03', '0x00', '0x10', '0x28']
# 		T1 NOTE->40
#      896 - ['0x80', '0x03', '0x20', '0x00', '0x3c', '0xe5', '0x07', '0x00']
# 		TEMPO->517436
#      897 - ['0x81', '0x03', '0x00', '0x11', '0x44', '0x47']
# 		T1 NOTE->68, T2 NOTE->71
#      960 - ['0xc0', '0x03', '0x20', '0x00', '0x6f', '0xed', '0x07', '0x00']
# 		TEMPO->519535
#     1016 - ['0xf8', '0x03', '0x00', '0x10', '0x34']
# 		T1 NOTE->52
#     1025 - ['0x01', '0x04', '0x00', '0x11', '0x40', '0x45']
# 		T1 NOTE->64, T2 NOTE->69
#     1088 - ['0x40', '0x04', '0x20', '0x00', '0x23', '0xa1', '0x07', '0x00']
# 		TEMPO->500003
#     1406 - ['0x7e', '0x05', '0x00', '0x10', '0x2d']
# 		T1 NOTE->45
#     1413 - ['0x85', '0x05', '0x00', '0x11', '0x45', '0x48']
# 		T1 NOTE->69, T2 NOTE->72
#     1533 - ['0xfd', '0x05', '0x00', '0x10', '0x39']
# 		T1 NOTE->57
#     1541 - ['0x05', '0x06', '0x00', '0x11', '0x48', '0x4c']
# 		T1 NOTE->72, T2 NOTE->76
#     1794 - ['0x02', '0x07', '0x00', '0x10', '0x39']
# 		T1 NOTE->57
#     1795 - ['0x03', '0x07', '0x00', '0x11', '0x47', '0x4a']
# 		T1 NOTE->71, T2 NOTE->74
#     1913 - ['0x79', '0x07', '0x00', '0x10', '0x2d']
# 		T1 NOTE->45
#     1921 - ['0x81', '0x07', '0x00', '0x11', '0x45', '0x48']
# 		T1 NOTE->69, T2 NOTE->72
#     2040 - ['0xf8', '0x07', '0x00', '0x10', '0x39']
# 		T1 NOTE->57
#     2049 - ['0x01', '0x08', '0x00', '0x11', '0x44', '0x47']
# 		T1 NOTE->68, T2 NOTE->71
#     2176 - ['0x80', '0x08', '0x00', '0x10', '0x2c']
# 		T1 NOTE->44
#     2184 - ['0x88', '0x08', '0x00', '0x10', '0x40']
# 		T1 NOTE->64
#     2303 - ['0xff', '0x08', '0x00', '0x10', '0x38']
# 		T1 NOTE->56
#     2311 - ['0x07', '0x09', '0x00', '0x10', '0x44']
# 		T1 NOTE->68
#     2430 - ['0x7e', '0x09', '0x00', '0x10', '0x2c']
# 		T1 NOTE->44
#     2437 - ['0x85', '0x09', '0x00', '0x11', '0x45', '0x48']
# 		T1 NOTE->69, T2 NOTE->72
#     2557 - ['0xfd', '0x09', '0x00', '0x10', '0x38']
# 		T1 NOTE->56
#     2565 - ['0x05', '0x0a', '0x00', '0x11', '0x47', '0x4a']
# 		T1 NOTE->71, T2 NOTE->74
#     2624 - ['0x40', '0x0a', '0x20', '0x00', '0x72', '0xb2', '0x07', '0x00']
# 		TEMPO->504434
#     2688 - ['0x80', '0x0a', '0x20', '0x00', '0x40', '0xba', '0x07', '0x00']
# 		TEMPO->506432
#     2752 - ['0xc0', '0x0a', '0x20', '0x00', '0x19', '0xc3', '0x07', '0x00']
# 		TEMPO->508697
#     2816 - ['0x00', '0x0b', '0x20', '0x00', '0x05', '0xd4', '0x07', '0x00']
# 		TEMPO->513029
#     2818 - ['0x02', '0x0b', '0x00', '0x10', '0x34']
# 		T1 NOTE->52
#     2819 - ['0x03', '0x0b', '0x00', '0x11', '0x48', '0x4c']
# 		T1 NOTE->72, T2 NOTE->76
#     2880 - ['0x40', '0x0b', '0x20', '0x00', '0x15', '0xdc', '0x07', '0x00']
# 		TEMPO->515093
#     2944 - ['0x80', '0x0b', '0x20', '0x00', '0x3c', '0xe5', '0x07', '0x00']
# 		TEMPO->517436
#     3008 - ['0xc0', '0x0b', '0x20', '0x00', '0x6f', '0xed', '0x07', '0x00']
# 		TEMPO->519535
#     3071 - ['0xff', '0x0b', '0x00', '0x10', '0x34']
# 		T1 NOTE->52
#     3073 - ['0x01', '0x0c', '0x00', '0x11', '0x45', '0x48']
# 		T1 NOTE->69, T2 NOTE->72
#     3136 - ['0x40', '0x0c', '0x20', '0x00', '0x23', '0xa1', '0x07', '0x00']
# 		TEMPO->500003
#     3335 - ['0x07', '0x0d', '0x00', '0x11', '0x40', '0x45']
# 		T1 NOTE->64, T2 NOTE->69
#     4095 - ['0xff', '0x0f', '0x00', '0x10', '0x30']
# 		T1 NOTE->48
#     4097 - ['0x01', '0x10', '0x00', '0x01', '0x32']
# 		T2 NOTE->50
#     4103 - ['0x07', '0x10', '0x00', '0x10', '0x32']
# 		T1 NOTE->50
#     4232 - ['0x88', '0x10', '0x00', '0x11', '0x41', '0x4a']
# 		T1 NOTE->65, T2 NOTE->74
#     4485 - ['0x85', '0x11', '0x00', '0x11', '0x45', '0x4d']
# 		T1 NOTE->69, T2 NOTE->77
#     4605 - ['0xfd', '0x11', '0x00', '0x10', '0x26']
# 		T1 NOTE->38
#     4613 - ['0x05', '0x12', '0x00', '0x11', '0x48', '0x51']
# 		T1 NOTE->72, T2 NOTE->81
#     4672 - ['0x40', '0x12', '0x20', '0x00', '0xc2', '0xa9', '0x07', '0x00']
# 		TEMPO->502210
#     4736 - ['0x80', '0x12', '0x20', '0x00', '0x72', '0xb2', '0x07', '0x00']
# 		TEMPO->504434
#     4864 - ['0x00', '0x13', '0x20', '0x00', '0x40', '0xba', '0x07', '0x00']
# 		TEMPO->506432
#     4866 - ['0x02', '0x13', '0x00', '0x11', '0x26', '0x48']
# 		T1 NOTE->38, T2 NOTE->72
#     4867 - ['0x03', '0x13', '0x00', '0x11', '0x48', '0x4f']
# 		T1 NOTE->72, T2 NOTE->79
#     4870 - ['0x06', '0x13', '0x00', '0x10', '0x47']
# 		T1 NOTE->71
#     4985 - ['0x79', '0x13', '0x00', '0x10', '0x2d']
# 		T1 NOTE->45
#     4992 - ['0x80', '0x13', '0x20', '0x00', '0x19', '0xc3', '0x07', '0x00']
# 		TEMPO->508697
#     4993 - ['0x81', '0x13', '0x00', '0x11', '0x45', '0x4d']
# 		T1 NOTE->69, T2 NOTE->77
#     5056 - ['0xc0', '0x13', '0x20', '0x00', '0x06', '0xcb', '0x07', '0x00']
# 		TEMPO->510726
#     5112 - ['0xf8', '0x13', '0x00', '0x10', '0x29']
# 		T1 NOTE->41
#     5120 - ['0x00', '0x14', '0x20', '0x00', '0x23', '0xa1', '0x07', '0x00']
# 		TEMPO->500003
#     5121 - ['0x01', '0x14', '0x00', '0x11', '0x43', '0x4c']
# 		T1 NOTE->67, T2 NOTE->76
#     5509 - ['0x85', '0x15', '0x00', '0x11', '0x40', '0x48']
# 		T1 NOTE->64, T2 NOTE->72
#     5629 - ['0xfd', '0x15', '0x00', '0x10', '0x30']
# 		T1 NOTE->48
#     5637 - ['0x05', '0x16', '0x00', '0x11', '0x43', '0x4c']
# 		T1 NOTE->67, T2 NOTE->76
#     5757 - ['0x7d', '0x16', '0x00', '0x10', '0x24']
# 		T1 NOTE->36
#     5764 - ['0x84', '0x16', '0x00', '0x10', '0x45']
# 		T1 NOTE->69
#     5822 - ['0xbe', '0x16', '0x00', '0x10', '0x2b']
# 		T1 NOTE->43
#     5826 - ['0xc2', '0x16', '0x00', '0x10', '0x43']
# 		T1 NOTE->67
#     5887 - ['0xff', '0x16', '0x00', '0x10', '0x2b']
# 		T1 NOTE->43
#     5891 - ['0x03', '0x17', '0x00', '0x11', '0x41', '0x4a']
# 		T1 NOTE->65, T2 NOTE->74
#     6009 - ['0x79', '0x17', '0x00', '0x10', '0x4a']
# 		T1 NOTE->74
#     6017 - ['0x81', '0x17', '0x00', '0x11', '0x40', '0x48']
# 		T1 NOTE->64, T2 NOTE->72
#     6136 - ['0xf8', '0x17', '0x00', '0x10', '0x2b']
# 		T1 NOTE->43
#     6145 - ['0x01', '0x18', '0x00', '0x11', '0x44', '0x47']
# 		T1 NOTE->68, T2 NOTE->71
#     6272 - ['0x80', '0x18', '0x00', '0x10', '0x2f']
# 		T1 NOTE->47
#     6280 - ['0x88', '0x18', '0x00', '0x10', '0x40']
# 		T1 NOTE->64
#     6399 - ['0xff', '0x18', '0x00', '0x10', '0x3b']
# 		T1 NOTE->59
#     6407 - ['0x07', '0x19', '0x00', '0x10', '0x44']
# 		T1 NOTE->68
#     6526 - ['0x7e', '0x19', '0x00', '0x10', '0x47']
# 		T1 NOTE->71
#     6533 - ['0x85', '0x19', '0x00', '0x11', '0x45', '0x48']
# 		T1 NOTE->69, T2 NOTE->72
#     6653 - ['0xfd', '0x19', '0x00', '0x10', '0x3b']
# 		T1 NOTE->59
#     6661 - ['0x05', '0x1a', '0x00', '0x11', '0x47', '0x4a']
# 		T1 NOTE->71, T2 NOTE->74
#     6781 - ['0x7d', '0x1a', '0x00', '0x10', '0x4a']
# 		T1 NOTE->74
#     6788 - ['0x84', '0x1a', '0x00', '0x10', '0x44']
# 		T1 NOTE->68
#     6907 - ['0xfb', '0x1a', '0x00', '0x10', '0x34']
# 		T1 NOTE->52
#     6915 - ['0x03', '0x1b', '0x00', '0x11', '0x48', '0x4c']
# 		T1 NOTE->72, T2 NOTE->76
#     7033 - ['0x79', '0x1b', '0x00', '0x10', '0x4c']
# 		T1 NOTE->76
#     7041 - ['0x81', '0x1b', '0x00', '0x10', '0x44']
# 		T1 NOTE->68
#     7160 - ['0xf8', '0x1b', '0x00', '0x10', '0x38']
# 		T1 NOTE->56
#     7169 - ['0x01', '0x1c', '0x00', '0x11', '0x45', '0x48']
# 		T1 NOTE->69, T2 NOTE->72
#     7296 - ['0x80', '0x1c', '0x00', '0x10', '0x2d']
# 		T1 NOTE->45
#     7304 - ['0x88', '0x1c', '0x00', '0x10', '0x40']
# 		T1 NOTE->64
#     7423 - ['0xff', '0x1c', '0x00', '0x10', '0x34']
# 		T1 NOTE->52
#     7431 - ['0x07', '0x1d', '0x00', '0x11', '0x40', '0x45']
# 		T1 NOTE->64, T2 NOTE->69
#     8193 - ['0x01', '0x20', '0x00', '0x11', '0x3c', '0x40']
# 		T1 NOTE->60, T2 NOTE->64
#     8709 - ['0x05', '0x22', '0x00', '0x11', '0x39', '0x3c']
# 		T1 NOTE->57, T2 NOTE->60
#     9215 - ['0xff', '0x23', '0x00', '0x10', '0x34']
# 		T1 NOTE->52
#     9217 - ['0x01', '0x24', '0x00', '0x11', '0x3b', '0x3e']
# 		T1 NOTE->59, T2 NOTE->62
#     9733 - ['0x05', '0x26', '0x00', '0x11', '0x38', '0x3b']
# 		T1 NOTE->56, T2 NOTE->59
#     9792 - ['0x40', '0x26', '0x20', '0x00', '0x72', '0xb2', '0x07', '0x00']
# 		TEMPO->504434
#     9856 - ['0x80', '0x26', '0x20', '0x00', '0x40', '0xba', '0x07', '0x00']
# 		TEMPO->506432
#     9920 - ['0xc0', '0x26', '0x20', '0x00', '0x19', '0xc3', '0x07', '0x00']
# 		TEMPO->508697
#     9984 - ['0x00', '0x27', '0x20', '0x00', '0x05', '0xd4', '0x07', '0x00']
# 		TEMPO->513029
#    10048 - ['0x40', '0x27', '0x20', '0x00', '0x15', '0xdc', '0x07', '0x00']
# 		TEMPO->515093
#    10112 - ['0x80', '0x27', '0x20', '0x00', '0x3c', '0xe5', '0x07', '0x00']
# 		TEMPO->517436
#    10176 - ['0xc0', '0x27', '0x20', '0x00', '0x6f', '0xed', '0x07', '0x00']
# 		TEMPO->519535
#    10239 - ['0xff', '0x27', '0x00', '0x10', '0x34']
# 		T1 NOTE->52
#    10241 - ['0x01', '0x28', '0x00', '0x11', '0x39', '0x3c']
# 		T1 NOTE->57, T2 NOTE->60
#    10304 - ['0x40', '0x28', '0x20', '0x00', '0x23', '0xa1', '0x07', '0x00']
# 		TEMPO->500003
#    10757 - ['0x05', '0x2a', '0x00', '0x11', '0x34', '0x39']
# 		T1 NOTE->52, T2 NOTE->57
#    10764 - ['0x0c', '0x2a', '0x00', '0x10', '0x2d']
# 		T1 NOTE->45
#    10884 - ['0x84', '0x2a', '0x00', '0x10', '0x34']
# 		T1 NOTE->52
#    11018 - ['0x0a', '0x2b', '0x00', '0x10', '0x2d']
# 		T1 NOTE->45
#    11137 - ['0x81', '0x2b', '0x00', '0x10', '0x34']
# 		T1 NOTE->52
#    11265 - ['0x01', '0x2c', '0x00', '0x01', '0x38']
# 		T2 NOTE->56
#    11271 - ['0x07', '0x2c', '0x00', '0x10', '0x2c']
# 		T1 NOTE->44
#    11400 - ['0x88', '0x2c', '0x00', '0x10', '0x34']
# 		T1 NOTE->52
#    11535 - ['0x0f', '0x2d', '0x00', '0x10', '0x2c']
# 		T1 NOTE->44
#    11653 - ['0x85', '0x2d', '0x00', '0x10', '0x34']
# 		T1 NOTE->52
#    11781 - ['0x05', '0x2e', '0x00', '0x11', '0x38', '0x3b']
# 		T1 NOTE->56, T2 NOTE->59
#    11840 - ['0x40', '0x2e', '0x20', '0x00', '0x72', '0xb2', '0x07', '0x00']
# 		TEMPO->504434
#    11904 - ['0x80', '0x2e', '0x20', '0x00', '0x40', '0xba', '0x07', '0x00']
# 		TEMPO->506432
#    11968 - ['0xc0', '0x2e', '0x20', '0x00', '0x19', '0xc3', '0x07', '0x00']
# 		TEMPO->508697
#    12032 - ['0x00', '0x2f', '0x20', '0x00', '0x05', '0xd4', '0x07', '0x00']
# 		TEMPO->513029
#    12096 - ['0x40', '0x2f', '0x20', '0x00', '0x15', '0xdc', '0x07', '0x00']
# 		TEMPO->515093
#    12160 - ['0x80', '0x2f', '0x20', '0x00', '0x3c', '0xe5', '0x07', '0x00']
# 		TEMPO->517436
#    12224 - ['0xc0', '0x2f', '0x20', '0x00', '0x6f', '0xed', '0x07', '0x00']
# 		TEMPO->519535
#    12287 - ['0xff', '0x2f', '0x00', '0x10', '0x34']
# 		T1 NOTE->52
#    12289 - ['0x01', '0x30', '0x00', '0x11', '0x3c', '0x40']
# 		T1 NOTE->60, T2 NOTE->64
#    12352 - ['0x40', '0x30', '0x20', '0x00', '0x23', '0xa1', '0x07', '0x00']
# 		TEMPO->500003
#    12805 - ['0x05', '0x32', '0x00', '0x11', '0x39', '0x3c']
# 		T1 NOTE->57, T2 NOTE->60
#    13311 - ['0xff', '0x33', '0x00', '0x10', '0x34']
# 		T1 NOTE->52
#    13313 - ['0x01', '0x34', '0x00', '0x11', '0x3b', '0x3e']
# 		T1 NOTE->59, T2 NOTE->62
#    13829 - ['0x05', '0x36', '0x00', '0x11', '0x38', '0x3b']
# 		T1 NOTE->56, T2 NOTE->59
#    14335 - ['0xff', '0x37', '0x00', '0x10', '0x34']
# 		T1 NOTE->52
#    14337 - ['0x01', '0x38', '0x00', '0x11', '0x39', '0x3c']
# 		T1 NOTE->57, T2 NOTE->60
#    14599 - ['0x07', '0x39', '0x00', '0x11', '0x3c', '0x40']
# 		T1 NOTE->60, T2 NOTE->64
#    14853 - ['0x05', '0x3a', '0x00', '0x11', '0x40', '0x45']
# 		T1 NOTE->64, T2 NOTE->69
#    15359 - ['0xff', '0x3b', '0x00', '0x10', '0x34']
# 		T1 NOTE->52
#    15361 - ['0x01', '0x3c', '0x00', '0x11', '0x40', '0x44']
# 		T1 NOTE->64, T2 NOTE->68
#    16383 - ['0xff', '0x3f', '0x00', '0x10', '0x34']
# 		T1 NOTE->52
# 945

# %%
len(buffer)
# Out:
# 945

# %%
buffer
# Out:
# ['0x00',
#  '0x00',
#  '0x20',
#  '0x33',
#  '0x00',
#  '0x00',
#  '0x00',
#  '0x00',
#  '0x23',
#  '0xa1',
#  '0x07',
#  '0x00',
#  '0x02',
#  '0x00',
#  '0x00',
#  '0x11',
#  '0x47',
#  '0x4c',
#  '0x07',
#  '0x01',
#  '0x00',
#  '0x11',
#  '0x44',
#  '0x47',
#  '0x7e',
#  '0x01',
#  '0x00',
#  '0x10',
#  '0x28',
#  '0x85',
#  '0x01',
#  '0x00',
#  '0x11',
#  '0x45',
#  '0x48',
#  '0xfd',
#  '0x01',
#  '0x00',
#  '0x10',
#  '0x34',
#  '0x05',
#  '0x02',
#  '0x00',
#  '0x11',
#  '0x47',
#  '0x4a',
#  '0x40',
#  '0x02',
#  '0x20',
#  '0x00',
#  '0x72',
#  '0xb2',
#  '0x07',
#  '0x00',
#  '0x7d',
#  '0x02',
#  '0x00',
#  '0x10',
#  '0x28',
#  '0x80',
#  '0x02',
#  '0x20',
#  '0x00',
#  '0x40',
#  '0xba',
#  '0x07',
#  '0x00',
#  '0x84',
#  '0x02',
#  '0x00',
#  '0x11',
#  '0x34',
#  '0x4c',
#  '0xc0',
#  '0x02',
#  '0x20',
#  '0x00',
#  '0x19',
#  '0xc3',
#  '0x07',
#  '0x00',
#  '0xc2',
#  '0x02',
#  '0x00',
#  '0x01',
#  '0x4a',
#  '0x00',
#  '0x03',
#  '0x20',
#  '0x00',
#  '0x05',
#  '0xd4',
#  '0x07',
#  '0x00',
#  '0x03',
#  '0x03',
#  '0x00',
#  '0x11',
#  '0x45',
#  '0x48',
#  '0x40',
#  '0x03',
#  '0x20',
#  '0x00',
#  '0x15',
#  '0xdc',
#  '0x07',
#  '0x00',
#  '0x79',
#  '0x03',
#  '0x00',
#  '0x10',
#  '0x28',
#  '0x80',
#  '0x03',
#  '0x20',
#  '0x00',
#  '0x3c',
#  '0xe5',
#  '0x07',
#  '0x00',
#  '0x81',
#  '0x03',
#  '0x00',
#  '0x11',
#  '0x44',
#  '0x47',
#  '0xc0',
#  '0x03',
#  '0x20',
#  '0x00',
#  '0x6f',
#  '0xed',
#  '0x07',
#  '0x00',
#  '0xf8',
#  '0x03',
#  '0x00',
#  '0x10',
#  '0x34',
#  '0x01',
#  '0x04',
#  '0x00',
#  '0x11',
#  '0x40',
#  '0x45',
#  '0x40',
#  '0x04',
#  '0x20',
#  '0x00',
#  '0x23',
#  '0xa1',
#  '0x07',
#  '0x00',
#  '0x7e',
#  '0x05',
#  '0x00',
#  '0x10',
#  '0x2d',
#  '0x85',
#  '0x05',
#  '0x00',
#  '0x11',
#  '0x45',
#  '0x48',
#  '0xfd',
#  '0x05',
#  '0x00',
#  '0x10',
#  '0x39',
#  '0x05',
#  '0x06',
#  '0x00',
#  '0x11',
#  '0x48',
#  '0x4c',
#  '0x02',
#  '0x07',
#  '0x00',
#  '0x10',
#  '0x39',
#  '0x03',
#  '0x07',
#  '0x00',
#  '0x11',
#  '0x47',
#  '0x4a',
#  '0x79',
#  '0x07',
#  '0x00',
#  '0x10',
#  '0x2d',
#  '0x81',
#  '0x07',
#  '0x00',
#  '0x11',
#  '0x45',
#  '0x48',
#  '0xf8',
#  '0x07',
#  '0x00',
#  '0x10',
#  '0x39',
#  '0x01',
#  '0x08',
#  '0x00',
#  '0x11',
#  '0x44',
#  '0x47',
#  '0x80',
#  '0x08',
#  '0x00',
#  '0x10',
#  '0x2c',
#  '0x88',
#  '0x08',
#  '0x00',
#  '0x10',
#  '0x40',
#  '0xff',
#  '0x08',
#  '0x00',
#  '0x10',
#  '0x38',
#  '0x07',
#  '0x09',
#  '0x00',
#  '0x10',
#  '0x44',
#  '0x7e',
#  '0x09',
#  '0x00',
#  '0x10',
#  '0x2c',
#  '0x85',
#  '0x09',
#  '0x00',
#  '0x11',
#  '0x45',
#  '0x48',
#  '0xfd',
#  '0x09',
#  '0x00',
#  '0x10',
#  '0x38',
#  '0x05',
#  '0x0a',
#  '0x00',
#  '0x11',
#  '0x47',
#  '0x4a',
#  '0x40',
#  '0x0a',
#  '0x20',
#  '0x00',
#  '0x72',
#  '0xb2',
#  '0x07',
#  '0x00',
#  '0x80',
#  '0x0a',
#  '0x20',
#  '0x00',
#  '0x40',
#  '0xba',
#  '0x07',
#  '0x00',
#  '0xc0',
#  '0x0a',
#  '0x20',
#  '0x00',
#  '0x19',
#  '0xc3',
#  '0x07',
#  '0x00',
#  '0x00',
#  '0x0b',
#  '0x20',
#  '0x00',
#  '0x05',
#  '0xd4',
#  '0x07',
#  '0x00',
#  '0x02',
#  '0x0b',
#  '0x00',
#  '0x10',
#  '0x34',
#  '0x03',
#  '0x0b',
#  '0x00',
#  '0x11',
#  '0x48',
#  '0x4c',
#  '0x40',
#  '0x0b',
#  '0x20',
#  '0x00',
#  '0x15',
#  '0xdc',
#  '0x07',
#  '0x00',
#  '0x80',
#  '0x0b',
#  '0x20',
#  '0x00',
#  '0x3c',
#  '0xe5',
#  '0x07',
#  '0x00',
#  '0xc0',
#  '0x0b',
#  '0x20',
#  '0x00',
#  '0x6f',
#  '0xed',
#  '0x07',
#  '0x00',
#  '0xff',
#  '0x0b',
#  '0x00',
#  '0x10',
#  '0x34',
#  '0x01',
#  '0x0c',
#  '0x00',
#  '0x11',
#  '0x45',
#  '0x48',
#  '0x40',
#  '0x0c',
#  '0x20',
#  '0x00',
#  '0x23',
#  '0xa1',
#  '0x07',
#  '0x00',
#  '0x07',
#  '0x0d',
#  '0x00',
#  '0x11',
#  '0x40',
#  '0x45',
#  '0xff',
#  '0x0f',
#  '0x00',
#  '0x10',
#  '0x30',
#  '0x01',
#  '0x10',
#  '0x00',
#  '0x01',
#  '0x32',
#  '0x07',
#  '0x10',
#  '0x00',
#  '0x10',
#  '0x32',
#  '0x88',
#  '0x10',
#  '0x00',
#  '0x11',
#  '0x41',
#  '0x4a',
#  '0x85',
#  '0x11',
#  '0x00',
#  '0x11',
#  '0x45',
#  '0x4d',
#  '0xfd',
#  '0x11',
#  '0x00',
#  '0x10',
#  '0x26',
#  '0x05',
#  '0x12',
#  '0x00',
#  '0x11',
#  '0x48',
#  '0x51',
#  '0x40',
#  '0x12',
#  '0x20',
#  '0x00',
#  '0xc2',
#  '0xa9',
#  '0x07',
#  '0x00',
#  '0x80',
#  '0x12',
#  '0x20',
#  '0x00',
#  '0x72',
#  '0xb2',
#  '0x07',
#  '0x00',
#  '0x00',
#  '0x13',
#  '0x20',
#  '0x00',
#  '0x40',
#  '0xba',
#  '0x07',
#  '0x00',
#  '0x02',
#  '0x13',
#  '0x00',
#  '0x11',
#  '0x26',
#  '0x48',
#  '0x03',
#  '0x13',
#  '0x00',
#  '0x11',
#  '0x48',
#  '0x4f',
#  '0x06',
#  '0x13',
#  '0x00',
#  '0x10',
#  '0x47',
#  '0x79',
#  '0x13',
#  '0x00',
#  '0x10',
#  '0x2d',
#  '0x80',
#  '0x13',
#  '0x20',
#  '0x00',
#  '0x19',
#  '0xc3',
#  '0x07',
#  '0x00',
#  '0x81',
#  '0x13',
#  '0x00',
#  '0x11',
#  '0x45',
#  '0x4d',
#  '0xc0',
#  '0x13',
#  '0x20',
#  '0x00',
#  '0x06',
#  '0xcb',
#  '0x07',
#  '0x00',
#  '0xf8',
#  '0x13',
#  '0x00',
#  '0x10',
#  '0x29',
#  '0x00',
#  '0x14',
#  '0x20',
#  '0x00',
#  '0x23',
#  '0xa1',
#  '0x07',
#  '0x00',
#  '0x01',
#  '0x14',
#  '0x00',
#  '0x11',
#  '0x43',
#  '0x4c',
#  '0x85',
#  '0x15',
#  '0x00',
#  '0x11',
#  '0x40',
#  '0x48',
#  '0xfd',
#  '0x15',
#  '0x00',
#  '0x10',
#  '0x30',
#  '0x05',
#  '0x16',
#  '0x00',
#  '0x11',
#  '0x43',
#  '0x4c',
#  '0x7d',
#  '0x16',
#  '0x00',
#  '0x10',
#  '0x24',
#  '0x84',
#  '0x16',
#  '0x00',
#  '0x10',
#  '0x45',
#  '0xbe',
#  '0x16',
#  '0x00',
#  '0x10',
#  '0x2b',
#  '0xc2',
#  '0x16',
#  '0x00',
#  '0x10',
#  '0x43',
#  '0xff',
#  '0x16',
#  '0x00',
#  '0x10',
#  '0x2b',
#  '0x03',
#  '0x17',
#  '0x00',
#  '0x11',
#  '0x41',
#  '0x4a',
#  '0x79',
#  '0x17',
#  '0x00',
#  '0x10',
#  '0x4a',
#  '0x81',
#  '0x17',
#  '0x00',
#  '0x11',
#  '0x40',
#  '0x48',
#  '0xf8',
#  '0x17',
#  '0x00',
#  '0x10',
#  '0x2b',
#  '0x01',
#  '0x18',
#  '0x00',
#  '0x11',
#  '0x44',
#  '0x47',
#  '0x80',
#  '0x18',
#  '0x00',
#  '0x10',
#  '0x2f',
#  '0x88',
#  '0x18',
#  '0x00',
#  '0x10',
#  '0x40',
#  '0xff',
#  '0x18',
#  '0x00',
#  '0x10',
#  '0x3b',
#  '0x07',
#  '0x19',
#  '0x00',
#  '0x10',
#  '0x44',
#  '0x7e',
#  '0x19',
#  '0x00',
#  '0x10',
#  '0x47',
#  '0x85',
#  '0x19',
#  '0x00',
#  '0x11',
#  '0x45',
#  '0x48',
#  '0xfd',
#  '0x19',
#  '0x00',
#  '0x10',
#  '0x3b',
#  '0x05',
#  '0x1a',
#  '0x00',
#  '0x11',
#  '0x47',
#  '0x4a',
#  '0x7d',
#  '0x1a',
#  '0x00',
#  '0x10',
#  '0x4a',
#  '0x84',
#  '0x1a',
#  '0x00',
#  '0x10',
#  '0x44',
#  '0xfb',
#  '0x1a',
#  '0x00',
#  '0x10',
#  '0x34',
#  '0x03',
#  '0x1b',
#  '0x00',
#  '0x11',
#  '0x48',
#  '0x4c',
#  '0x79',
#  '0x1b',
#  '0x00',
#  '0x10',
#  '0x4c',
#  '0x81',
#  '0x1b',
#  '0x00',
#  '0x10',
#  '0x44',
#  '0xf8',
#  '0x1b',
#  '0x00',
#  '0x10',
#  '0x38',
#  '0x01',
#  '0x1c',
#  '0x00',
#  '0x11',
#  '0x45',
#  '0x48',
#  '0x80',
#  '0x1c',
#  '0x00',
#  '0x10',
#  '0x2d',
#  '0x88',
#  '0x1c',
#  '0x00',
#  '0x10',
#  '0x40',
#  '0xff',
#  '0x1c',
#  '0x00',
#  '0x10',
#  '0x34',
#  '0x07',
#  '0x1d',
#  '0x00',
#  '0x11',
#  '0x40',
#  '0x45',
#  '0x01',
#  '0x20',
#  '0x00',
#  '0x11',
#  '0x3c',
#  '0x40',
#  '0x05',
#  '0x22',
#  '0x00',
#  '0x11',
#  '0x39',
#  '0x3c',
#  '0xff',
#  '0x23',
#  '0x00',
#  '0x10',
#  '0x34',
#  '0x01',
#  '0x24',
#  '0x00',
#  '0x11',
#  '0x3b',
#  '0x3e',
#  '0x05',
#  '0x26',
#  '0x00',
#  '0x11',
#  '0x38',
#  '0x3b',
#  '0x40',
#  '0x26',
#  '0x20',
#  '0x00',
#  '0x72',
#  '0xb2',
#  '0x07',
#  '0x00',
#  '0x80',
#  '0x26',
#  '0x20',
#  '0x00',
#  '0x40',
#  '0xba',
#  '0x07',
#  '0x00',
#  '0xc0',
#  '0x26',
#  '0x20',
#  '0x00',
#  '0x19',
#  '0xc3',
#  '0x07',
#  '0x00',
#  '0x00',
#  '0x27',
#  '0x20',
#  '0x00',
#  '0x05',
#  '0xd4',
#  '0x07',
#  '0x00',
#  '0x40',
#  '0x27',
#  '0x20',
#  '0x00',
#  '0x15',
#  '0xdc',
#  '0x07',
#  '0x00',
#  '0x80',
#  '0x27',
#  '0x20',
#  '0x00',
#  '0x3c',
#  '0xe5',
#  '0x07',
#  '0x00',
#  '0xc0',
#  '0x27',
#  '0x20',
#  '0x00',
#  '0x6f',
#  '0xed',
#  '0x07',
#  '0x00',
#  '0xff',
#  '0x27',
#  '0x00',
#  '0x10',
#  '0x34',
#  '0x01',
#  '0x28',
#  '0x00',
#  '0x11',
#  '0x39',
#  '0x3c',
#  '0x40',
#  '0x28',
#  '0x20',
#  '0x00',
#  '0x23',
#  '0xa1',
#  '0x07',
#  '0x00',
#  '0x05',
#  '0x2a',
#  '0x00',
#  '0x11',
#  '0x34',
#  '0x39',
#  '0x0c',
#  '0x2a',
#  '0x00',
#  '0x10',
#  '0x2d',
#  '0x84',
#  '0x2a',
#  '0x00',
#  '0x10',
#  '0x34',
#  '0x0a',
#  '0x2b',
#  '0x00',
#  '0x10',
#  '0x2d',
#  '0x81',
#  '0x2b',
#  '0x00',
#  '0x10',
#  '0x34',
#  '0x01',
#  '0x2c',
#  '0x00',
#  '0x01',
#  '0x38',
#  '0x07',
#  '0x2c',
#  '0x00',
#  '0x10',
#  '0x2c',
#  '0x88',
#  '0x2c',
#  '0x00',
#  '0x10',
#  '0x34',
#  '0x0f',
#  '0x2d',
#  '0x00',
#  '0x10',
#  '0x2c',
#  '0x85',
#  '0x2d',
#  '0x00',
#  '0x10',
#  '0x34',
#  '0x05',
#  '0x2e',
#  '0x00',
#  '0x11',
#  '0x38',
#  '0x3b',
#  '0x40',
#  '0x2e',
#  '0x20',
#  '0x00',
#  '0x72',
#  '0xb2',
#  '0x07',
#  '0x00',
#  '0x80',
#  '0x2e',
#  '0x20',
#  '0x00',
#  '0x40',
#  '0xba',
#  '0x07',
#  '0x00',
#  '0xc0',
#  '0x2e',
#  '0x20',
#  '0x00',
#  '0x19',
#  '0xc3',
#  '0x07',
#  '0x00',
#  '0x00',
#  '0x2f',
#  '0x20',
#  '0x00',
#  '0x05',
#  '0xd4',
#  '0x07',
#  '0x00',
#  '0x40',
#  '0x2f',
#  '0x20',
#  '0x00',
#  '0x15',
#  '0xdc',
#  '0x07',
#  '0x00',
#  '0x80',
#  '0x2f',
#  '0x20',
#  '0x00',
#  '0x3c',
#  '0xe5',
#  '0x07',
#  '0x00',
#  '0xc0',
#  '0x2f',
#  '0x20',
#  '0x00',
#  '0x6f',
#  '0xed',
#  '0x07',
#  '0x00',
#  '0xff',
#  '0x2f',
#  '0x00',
#  '0x10',
#  '0x34',
#  '0x01',
#  '0x30',
#  '0x00',
#  '0x11',
#  '0x3c',
#  '0x40',
#  '0x40',
#  '0x30',
#  '0x20',
#  '0x00',
#  '0x23',
#  '0xa1',
#  '0x07',
#  '0x00',
#  '0x05',
#  '0x32',
#  '0x00',
#  '0x11',
#  '0x39',
#  '0x3c',
#  '0xff',
#  '0x33',
#  '0x00',
#  '0x10',
#  '0x34',
#  '0x01',
#  '0x34',
#  '0x00',
#  '0x11',
#  '0x3b',
#  '0x3e',
#  '0x05',
#  '0x36',
#  '0x00',
#  '0x11',
#  '0x38',
#  '0x3b',
#  '0xff',
#  '0x37',
#  '0x00',
#  '0x10',
#  '0x34',
#  '0x01',
#  '0x38',
#  '0x00',
#  '0x11',
#  '0x39',
#  '0x3c',
#  '0x07',
#  '0x39',
#  '0x00',
#  '0x11',
#  '0x3c',
#  '0x40',
#  '0x05',
#  '0x3a',
#  '0x00',
#  '0x11',
#  '0x40',
#  '0x45',
#  '0xff',
#  '0x3b',
#  '0x00',
#  '0x10',
#  '0x34',
#  '0x01',
#  '0x3c',
#  '0x00',
#  '0x11',
#  '0x40',
#  '0x44',
#  '0xff',
#  '0x3f',
#  '0x00',
#  '0x10',
#  '0x34',
#  '0x00',
#  '0x00',
#  '0x80',
#  '0x00']
